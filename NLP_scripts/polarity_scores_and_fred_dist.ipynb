# %%
import pandas as pd
import numpy as np
import nltk
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

survey_data = pd.read_excel('data/raw_data.xlsx')


def clean_data(data):
    # This function takes an array of strings and returns an array of cleaned up strings
    cleaned_data = []
    for row,texts in enumerate(data):
        texts = str(texts)
        texts = texts.lower()
        # remove special characters
        texts = texts.replace(r"(http|@)\S+", "")
        texts = texts.replace(r"::", " ")
        texts = texts.replace(r"’", "")
        texts = texts.replace(r",", " ")
        texts = texts.replace(r"[^a-z\':_]", " ")
        # remove repetition
        #pattern = re.compile(r"(.)\1{2,}", re.DOTALL)
        #texts = texts.replace(pattern, r"\1")
        # Transform short negation form
        texts = texts.replace(r"(can't|cannot)", 'can not')
        texts = texts.replace(r"n't", ' not')
        # Remove stop words
        stopwords = nltk.corpus.stopwords.words('english')
        stopwords.remove('not')
        stopwords.remove('nor')
        stopwords.remove('no')
        cleaned_line = ''
        for word in texts.split(" "):
            if word not in stopwords:
                cleaned_line = cleaned_line + " " + word
        cleaned_data.append(cleaned_line)
    return cleaned_data

columns_with_open_responses = ['Q02', 'Q04', 'Q06', 'Q08', 'Q10', 'Q12', 'Q14', 'Q16', 'Q18']
data = survey_data[columns_with_open_responses]
data = data.reset_index()
data = data[1:]
data = data.drop(columns = ['index'])
all_values = []
for column in data:
    this_column_values = data[column].tolist()
    all_values += this_column_values
one_column_df = pd.DataFrame(all_values)
one_column_df = one_column_df.dropna()
data = one_column_df.reset_index()
data = data.drop(columns = ['index'])
data = np.array(data)
data = clean_data(data)

# %%
data
# Out:
# [' ["i not provided info yet"]',
#  " ['not able access ato site complete basic reporting  pathetic waste time.repeatedly denied access shut   .. truly waste time utter garbag!!! someone fet paid  taxpayers money put crap together joke  think people hours waste trying sort shit out??!! stipped sending bas forms? dont want paet lame malfunctioning computer system ! regulwr paper bas forms remove worthless shit computer system!!e!!']",
#  ' ["the operator great i\'d code pkr040"]',
#  " ['as initiatives  concerns not handle technology well ']",
#  " ['cant login ']",
#  " ['information requests keep piling due date!']",
#  " ['i writing behalf partner parkinsons disease. according ndis must access centrelink himself. neurological problems make difficult. frozen account three times. trying open another new account  site wont allow this. easier way/']",
#  " ['seems except layout first glance']",
#  " ['im trying create account months always come back wrong attempts im lock ']",
#  " ['due fact gov login page locked account putting password correctly. ask question online chat took circles incorrect information answers']",
#  ' ["i not looking particular information  curious website looked like."]',
#  " ['i recently updated information assets centrelink found new site much harder use previous layout complex not enough space one box enter bank account numbers.']",
#  " ['i cant access mygov website overseas dont mobile phone linked mygov back australia. would helpful able use mygov id log mygov without link mygov id mygov account within mygov. ']",
#  ' ["it\'s limited options  rather providing full access every department. seems suggest options  not let anything else. hardly features  ca not really evaluated."]',
#  " ['i could access need easily ']",
#  " ['i previously able get gov. todays experience nightmare sent around circles. poor communications - loads words instructions dont go anywhere. ']",
#  " ['nothing easy find. no information specific.']",
#  " ['me insider hospital metals clinic footscray renew outside no money value. help thanks much.']",
#  " ['cunts frauds hacked ']",
#  " ['signjng- difficult. ']",
#  " ['thank much ']",
#  " ['theres no reason ']",
#  " ['deadset useless cunts yous ']",
#  " ['the  beauracratic brains  behind website   less  useful. ']",
#  " ['i thought feedback form! password criteria bullshit. log onto mygov year tax impossible remember password account permanently locked!!!!! painful']",
#  ' ["i\'m trouble getting gov activate ndis code "]',
#  " ['after successfully login account :  jk728811  screen displayed “  loading please wait upper address bar running many many “auth callback” code addresses 5 minutes  back !!!!   gone !   ']",
#  ' ["because ca not log in. mobile number different phone wo not generate code"]',
#  " ['tried create account without success. cannot access account']",
#  " ['easily understood ']",
#  " ['because trouble pass word. keeps blocking fear security']",
#  " ['some one hacking personal  gov details removing  teleohone address replaging own. believe itis coming 7 chesterfield drive wyndham  vale female relative visiting driving car must false licence no gp would let herdrive.she hardly walk looks 100 years old.']",
#  " ['no explanation shut out']",
#  " ['too much']",
#  " [' ']",
#  " ['the information found helpful. page right?']",
#  " ['detailed']",
#  " ['the centrelink income stream update unusable -it asks amount commutation not made not take 0 answer']",
#  " ['good']",
#  " ['i saw fro log site']",
#  " ['i sees things actually designed like ']",
#  ' [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  " ['there no trouble shooting help page.']",
#  " ['i trying contact mygov problem encountered recently.']",
#  " ['it somewhat helpful. website keeps jumping back sign page  frustrating']",
#  " ['switching account services made use website much harder less user friendly']",
#  " ['your stupid line chat service not answer questions? waste time energy!!!!!']",
#  " ['everytime update change app  nothing issues. stop updates buy updated phone']",
#  " ['i found need easily ']",
#  " ['was really easy find everything looking for']",
#  ' ["the \'update assets\' sections much better (less lengthier point/all one page) original version. new area requires constant clicking new fields submission.  "]',
#  " ['saw helpful things easily like tasks  payments services']",
#  " ['i looking get csa  could not find it. could find could apply new assessment  not wanted.']",
#  " ['i wanted access mygov inbox. able to']",
#  " ['your website fucked!locked entered correct info password questions ']",
#  " ['inbox messages not clearly visible. tax information not visible.']",
#  " ['i could not access account old mobile number attached it.']",
#  " ['may please delete mygov account. username: elvis.nguyen.zero@gmail.com']",
#  " ['totally confused not understanding many questions site wanted log login get another text log in']",
#  " ['its nightmare start et able finush']",
#  " ['could not get app locked 2 hours said get app gave wrong answer ']",
#  " ['not useful']",
#  " ['eaiser understand']",
#  " ['just difficult many steps']",
#  " ['there no response;to complain ']",
#  " ['i make phone call try sort problem still no access account.']",
#  ' [\'the stock images dominate page much mind. like "jump topic" section\']',
#  " ['using mygovid app useless']",
#  " ['i agreed fact  information found helpful.']",
#  ' [\'the problem remains solved update issues faced simply trying login account. cannot login  services available  no matter well designed information  easily found  cannot used first place. not believe ever experience logging mygov occurred without issue  whether australia overseas. present  required set secure login password  serves almost no purpose always required enter code. beauty process code must either sent text message  \\\'generator app\\\'  course  phone. unhelpful don\\\'t access phone  not mention infuriating solution "i cannot access device/i lost device (i.e. app installed)"  "select receive sms". possible receive sms device not  fact not reason you\\\'re stuck first place?  accept 2021 need receive code addition password every single time login  code generator app sounds amazing! problem  doesn\\\'t work - see return scenario outlined  alternatively  you\\\'re overseas haven\\\'t lost device per se  still cannot receive sms: end result. back code generator app itself. managed use one  going process setting up. set app  to.... guessed - login! using sms receive code! hilarious considering setting precisely not use sms code  better hope remember set realise need (magic future telling powers required). manage foresight  somehow thought would save repeating nightmare circle dance logging mygov  think cracked it! however  trying use simple sounding login password + secret code generator app today  open app find without code. set scene: website simply says "enter code mygov code generator app. didn\\\'t get code? click send code via sms". app says  "about app: app generates codes enter sign mygov account. you\\\'ve set app  can..." oh  helpful. point options are: (1) request code via sms - cannot receive sms\\\'s overseas  course set app first place (refer first problem mentioned). (2) select \\\'continue\\\' app - beautiful thing. select continue takes process setting account. re-enter login details  useless password  hit submit.  says pure comedy gold: "your device already registered. please login remove device want set again". yes  that\\\'s right. app need use login telling need login use it. not need explain ridiculous is. course  remaining option call centerlink   alas  line hangs time get through. want finish tax return  all.  spending incredible amount money bring website content visuals user accessibility 21st century  please ensure users actually access traditional sense word - simply login. without basic functionality  site entirely useless. thanks advance! regards  tax payer.  \']',
#  " ['its seems high level safty']",
#  " ['non']",
#  " ['too complex  especially older australians. seems worked clever ways exclude. e.g ahange phones.']",
#  " ['i able read notice inbox unable sign site']",
#  " ['i unable update address - tried many times.  asked provide proof birth dropdown options no option proof birth - children listed. uploaded information messaged provide proof birth. upload one  kids names still no option dropdown upload birth certificate. hugely frustrating started claim 30/12/20. cant get thru phones either boxwhen asked provide information']",
#  " ['why keep asking email address password?']",
#  " ['because hoops making jump thru login ridiculous. code generator doesnt work whole process sends circles. bloody ridiculous ']",
#  ' ["there not anything could help"]',
#  " ['i spoke rude disinterested young female clearly not suffient training regarding email release whi asked anything else hung befire could reply....what heck wrong people....the previous man spoke amazingly courteous.....please call back explain....0421968108  debbie breen.']",
#  " [' expresses clear true ']",
#  " ['the new site appears triumph design practicality.  hard find information- using phone tablet image tiles big no indication scrolling required- not far options user is. could not find centrelink assume not there. options task based no easily visible information go none options seemed cover wanted do. ']",
#  " ['i many issues using latest update report employment income.']",
#  " ['the whole thing ambiguous circuitous']",
#  ' ["as member community housing provider (affiliated housing sa)  required twice yearly provide income information external housing provider called common equity. common equity requested contact centrelink request \'statement income\' centrelink end last financial year order assess rent payable. upon time stated senior centrelink  information readily available provided. no longer case  could mean tenant public housing  may well end paying full ceiling rent not provided sufficient documentation income. centrelink withdrawn access summary end financial year income statements accessible printable?"]',
#  ' ["your beta version govid process medicare claims painful exercise  simplify authentication process authentication instead rubbish mygov code  whole via not working. i\'m definitely never going use app again! "]',
#  " ['from years experience. ']",
#  " ['too many steps arrive point. much reading. much repetition. must extremely difficult non english speakers. old system centrelink reporting far user friendly!!']",
#  " ['the site bad  clunky trying link accounts nightmare 12 year old could design better website ']",
#  " ['not everything require file']",
#  " ['because interaction stress free.']",
#  " ['convoluted confusing']",
#  " ['nothing provided assisted problem']",
#  ' ["ive beentrying update bank details went video updating details not icon menu tbe video mentioned trying update finding solution"]',
#  ' ["ask password not sent come usaying sent not "]',
#  " ['some confusing']",
#  ' ["i trying complete grant application (tourism support) services australia.  need ato tax certificate.  trying penetrate ato website instructions certificate almost impossible (and commercial lawyer 30 years experience).  however absurd thing (and mygov relevance) ultimately certificate generated paper sent post !  surely commonwealth government claims trying things digitally  still operating system offocial documents sent post [snail mail...] current mygov account holders ridiculous!  noticed no improvements cutting government bureaucracy red tape past 25 years  despite rhetoric!.  need design implement world\'s best practice systems.  sending pieces paper letterboxes 2021 not meet description!"]',
#  " ['my details not changed get report']",
#  " ['very helpful']",
#  " ['couldny find ct scan information self even though done couple weeks ago']",
#  " ['n/a.']",
#  " ['not getting code link email phone']",
#  " ['i need speak someone  system loop cant get help need']",
#  " ['integration good idea']",
#  " ['because information was']",
#  " ['i didnt notice new information ']",
#  " ['my problem centrelink site']",
#  " ['it info ive seen previously tried put better way']",
#  " ['cant use forgot password tab']",
#  " ['i looking login screen  used seeing.  going remove  understand  would like suggest putting quick link top right bottom amongst links.  whilst site informative people want get get need assist them.  believe site must address lower level user knowledge.  otherwise leaving sued olympic committee australian olympics. ']",
#  ' [\'because "secret questions" aleays wrong accound keeps loccking\']',
#  " ['centre link supposed linked my.gov yet put information again. drop boxes not relate asked download. incredibly cumbersome. information asked pointless. someone already stress making ill bring navigate 3 university degrees.']",
#  " ['limited online functionality forces call multiple occasions resolve matter coupled excessive hold times no call back service offered you']",
#  " ['can not access gov no phone access']",
#  ' ["i changed (i thought) going easier time logging mygov  using strongly recommented mygovid???????  joke  cannot login either   great job!!!!!! due  cannot access max...so got cut centrelink  again...suspended automatically max... beg get put back on.. mygovid total joke  better hope information not get hacked... i\'ve read article   finishing setting new mygov.  mygov not recognise passwords...old new one mygovid. great jobs guys  whoever developed dismissed immediately. no doubt suspended  cutoff centrelink   again"]',
#  " ['i dont see use all. go round round dont seem get anywhere. ive no idea use mygovid is. still log centrelink seperately']",
#  " ['this site useless']",
#  " ['because forgot password  code never sent email address mobile. secret questions seemed not available']",
#  " ['either info incorrect site bugged']",
#  " ['my answer']",
#  " ['i havi g trouble wirh website']",
#  " ['i think ']",
#  " ['because says change phone number account settings login select account tried keep getting code sent phone number dont number moment head im not good ']",
#  " ['easy get information ']",
#  " ['because want simple change address area/position website']",
#  ' [\'i unable easily look balances mygov holds accounts.  need go "updates" see  even not wish change balances.\']',
#  " ['because helpful ']",
#  ' ["the digital voice could not recognise voice properly letter end numerals continually repeated information became frustrated."]',
#  ' ["i unable sign-up centrelink using phone worse app sign told current affair horrible  experience get work better!"]',
#  " ['i cant link medicare. mygov ask step step process type medicare card details enter  type name dob enter  type address enter. asked details doesnt match doesnt go next stage.  user doesnt know one not correct.']",
#  " ['absolutely worst app ever used']",
#  " ['i easily found information looking for.']",
#  " ['it ok introduction']",
#  " ['another private firm given private information get rich exploiting disadvantaged help liberals destroy social security. shame making life harder poverty']",
#  " ['very easy follow page layout']",
#  " ['when contacted centalink complaints found quite difficult.  tried call back once. position unable take call. no callback number call come private number.']",
#  " ['i denied job seekers  claim didnot complete jobseekers snap shot. jobseekers app no clear instuctions complete kobseekers snapshot']",
#  " ['i live outside australia not easy make call. help services extremely user unfriendly. systems backwards say least. desperate need assistance yet design services least assistance. craig upjohn +66928255579']",
#  " ['your apps logins useless  trash']",
#  ' ["i understand trialling page centrelink services.  no easy way find page  case scroll  scroll  scroll see  even centrelink service not anyway.  sort menu  allowing pick service would much useful."]',
#  " ['attempted numerous times link medicare mygov using linking code filling alternative link questions system not working.']",
#  ' [\'the "my.gov.au" not respond.  "mygov" went indian government site.  finally got  don\\\'t know  site would not recognise username. always bugger  site  got worse  quite suddenly\']',
#  ' ["typical gov cannot access anything  i\'m trying access. goes back forth without achieving anything.  basic login not basic "]',
#  " ['i couldnt vote legislation 2fa app  track political donations real time blockchain']",
#  " ['at least get firefox  instead use chrome  mainsite']",
#  " ['coz lost phone number cant login.even hav password govid ']",
#  " ['the site maintainance information extent not avaiable logged in. no information lenght delay.']",
#  " ['i mygov account cannot access it. old lady 71 cannot remember password answers questions.  wrote somewhere.  now?']",
#  " ['no full explanation unsuccessfully reset password ']",
#  " ['there no help person ']",
#  " ['unable log mygov all. soon try sign not load log returns sign page. details correct.']",
#  " ['the website doesnt load ']",
#  " ['ive followed app details registered  use website doesnt link!']",
#  " ['the information spread out. many tiles distracting. ']",
#  " ['you try tell not know answers secret questions ']",
#  " ['my wife never read mail not log without something going wrong']",
#  " ['it good ']",
#  " ['your app locks password reset never works test shit release fools']",
#  " ['because makes easy understand']",
#  ' ["dont\' count / sa checking form"]',
#  " ['my gov helpful creating starting account well contact support im lost']",
#  ' ["tried log username password many times. not work!!"]',
#  " ['could not find looking for']",
#  " ['well thought still info screen beta experience appear  bottom looking ok next button! keen   thought  lets this! said ok  it? point little confused worked wasnt info screen may appear  actual mygov beta website. truth didnt really try links (believing demo photos  not actual links) dont feel got go mygov beta yet. asked it? felt ripped off! like missed out! mention im autistic  best possible way though. broken every iq test since first one 12yo rating 147. every iq test since says maxed 150  dont believe iq tests true  otherwise im smart struggle every single day complete basic daily tasks????']",
#  " ['because annoyed n everything written not help me']",
#  " ['your website sends clients pointless loops ']",
#  ' ["i used open letter  pay payg account. waste time trying understand message ca not print copy notice"]',
#  " ['i stranded resident overseas  want pay payg  require australian sim card site rejected secret word  pay']",
#  " ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  " ['the hole system not working hard use ']",
#  ' ["it\'s true"]',
#  " ['need simple answer question  incredibly hard get answer phone system']",
#  ' ["because tried reset password answers questions said wrong not wrong"]',
#  " ['i tried change password mygov sending another username  not password ??????????']",
#  " ['strongly agree']",
#  " ['ino reason']",
#  " ['the need obtain app code renter username password means code expired time get field enter it.  need freeze user name password go field get app code.']",
#  " ['too b...y complex.   didnt end getting mygov 😡']",
#  " ['think good']",
#  " ['due fact changed mobile number unable login mygov - didnt access verification code. phone also cant call unable call help desk. ']",
#  " ['agree ']",
#  " ['i got no help accessing mygov inbox']",
#  ' ["because could not find information looking went old site. centrelink sent letter update form much easier find centrelink click form using old site. not want read documents portal - use google anything informational better."]',
#  " ['i enter everyday email ..its  not accepted.. says need new email .. enter mobile number also not accepted   need find new email new mobile number sign ??? crn link code  centerlink cant  put anywhere always says email invalid ..yet centerlink office  front staff member good']",
#  " ['it not work  every time try log problem. ']",
#  ' ["confusing website. not seem date many links websites defeats purpose "]',
#  ' ["i wanted find messages ato  no idea find them. would prefer clear simple navigation shows eg. \'ato\'  \'medicare\'  etc"]',
#  " ['everytime insert username password select confirm password disappears try account locks up. really difficult! ive reset unlocked several times keeps occurring. still cant access account. wonder dont engaged why. cant!']",
#  " ['limited control function elongated pages']",
#  " ['once linked mygov medicare & ato  proving identity automatic ']",
#  " ['useless']",
#  ' ["no matter try  email address use  still ca not access mygov site.  supposedly pending messages actions complete.  great effort "]',
#  " ['i preferer old layout linked services only']",
#  " ['it confusing not work time']",
#  " ['i called overseas international phone cost  connected person talikng hang way coversation. need help phone hang centrelink.']",
#  " ['it frustrating completing application seniors health care card.  first  not accept bank account details. secondly  not accept id documentation - not tell us go centrelink office provide id. ']",
#  " ['very frustrating  unable log   password rejected several times responses security questions not accepted ']",
#  " ['my gov nothing crap cant things go back like gov']",
#  " ['hello 👋 ']",
#  " ['your help desk phones keep dropping  spent 90 mins today trying get help  plus questions answered web site regurgitates stock info not answer service']",
#  ' ["how instead making second \'improved site\' make one works upgrade infrastructure"]',
#  " ['have spent two hours trying update assets banking  site not let continue entering dates  even though entered format requested.']",
#  " ['tasks within linked services appear mygov dashboard.']",
#  " ['currently  beta site portal  linked services log redirect old site. confusing. ']",
#  " ['cause']",
#  " ['this not intuitive app. information difficult find format data displayed poor.']",
#  " ['unable access mygov account new mobile number']",
#  " ['information provided valuable bit overwhelming initially ']",
#  " ['sent chase no apparent result.']",
#  " ['i unable log even though details correct']",
#  " ['the lost email lost password numbers.l entered not work. you. make bloody hard open anything password generated. not work.']",
#  " ['eat shit']",
#  " ['i tried access account using email address password came back details wrong typed forgot password got code  came back temporally locked out.not happy']",
#  " ['looks good follow world standards info sites well done']",
#  " ['because mygov easy efficient use always find useful helpful information']",
#  " ['veryhard find relevant answers. no phone number included']",
#  " ['i pretty used it.  however  find site obstructive use crns link services centrelink. added [youth allowance] parental income children successfully generated crn not me.  one gets stuck frustrating loop selecting not crn appears no affect.  honestly no idea whether not even online centrelink account even though entered details  mygov acc. mygovid.  nothing syncs!']",
#  " ['because edit phone number ring you; something previous experiance takes long time get all!!']",
#  " ['site not accepting correct day/date format personal drtails update section. multiple attempts made  tried logging back complete details everytime. probably go back centrelink try get resolved there. bad enough got terminated today.i also difficult time 3 years ago  first time ever tried get govt help due not able secure employment.']",
#  " ['my password changes random threaten permanently bar me']",
#  " ['hopeless not even medicare located gov.']",
#  " ['if system crashed  not provide service']",
#  " ['i need slightly tweak residential address appearing incorrectly. no option make edit. focussed fact changing something meant moving. im not. name tania mcinnes. residential address needs read following way file: 184 knights hill road knights hill 2577 nsw. thank :)']",
#  " ['the information date answered questions looking for']",
#  " ['the older generation not savvy']",
#  " ['saves time & sale free moments ringing agencies.']",
#  " ['unsatisfactory']",
#  " ['because system not work still ring up']",
#  " ['the information website fine']",
#  " ['cant access account again.....']",
#  " ['this worst thing get  terrible']",
#  " ['because help desk number not readily listed.']",
#  " ['the layout information flows natural engaging manner. compare experience recent encounter attempting navigate seemingly endless blue hyperlink trail plethora available assistance visually hard digest alphabetical organisation list led disarray instead grouped easily followed reaource.']",
#  " ['fucking shit cant even log  gov account']",
#  " ['there no easy way get passwords forget them']",
#  " ['this hardest website get locked cannoit use ']",
#  " ['the websit no help all. useless']",
#  " ['because trying login gov forget login username sent request sent email 4 times still nothing yet']",
#  ' ["it wo not  give everything  "]',
#  " ['your website doesnt work']",
#  " ['i get information']",
#  " ['where allowance payments worked  support pension payments allowance ...... disability pension support allowance dole payments dole payments allowance disa ']",
#  " ['this difficult website navigate  no idea set access pathology report']",
#  " ['i never get on. worst app made']",
#  " ['the staff useless']",
#  ' ["keep going around circles unable link gov i\'d amy gov account  user unfriendly."]',
#  " ['please ignore previous response form  trial error found needed open my.gov computer receiving codes via mobile phone. not noted attempting complete entire process phone proved impossible.']",
#  " ['all tech much hard link anything log in']",
#  ' ["the language used not consistent  amount double ups information needed presented ridiculous  no government officer knows info next  fairly contradictory."]',
#  " ['the site laid well easy navigate.']",
#  " ['ttyt']",
#  " ['easy undaerstand']",
#  ' ["i not look information reporting"]',
#  " ['i hate getting sms code want log in']",
#  " ['theres no choices shown future gov look like ']",
#  " ['because doesnt work']",
#  " ['it nothing age pension']",
#  " ['mygov intimidating unfriendly. uses jargon']",
#  " ['?? information']",
#  " ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  " ['was easy get help need']",
#  ' ["because never login \'mygov\' account  one occasion manage  got sent around circles  ended confused  headache."]',
#  " ['the online process not supported action ']",
#  " ['use gov app tiresome not easy use using old centrelink login']",
#  " ['it impossible log mygov  & system not send username password codes details havnt changed. terribly stressful system not let log exceedingly long times. lost house 2019 fires & tax department intimidating cant lodge 3 years tax lost everything except shorts & torn shirt. nothing & tax department wants money form :(']",
#  " ['on line lodgement need back turn around times  offer online updates never actioned']",
#  " ['it seems current mygov']",
#  " ['because report income receipt required. sometimes may forget print it. happened could get copy dashboard cannot removed. put back please!']",
#  ' [\'i get new phone number could no longer log mygov insisted verifying via phone secure code. get new email address sign new account. "help desk" people useless. zero help. \']',
#  " ['no didnt work. no info provided wanted ']",
#  ' [\'accepting beta testing actual activity flicks back "real" website question think everyone ask changing site. new site looks fine  need get used neither better nor worse old one. think sentences everyones needs re-learn get around would helpful  please no fuffy nonesence like "we trying make mygov nicer experience making  site easier  navigate" thats meaningless rubbish also goimg tell people new site "more secure" immediately raise questions unsecurity old site ( ie current site ).  millions taxpayer dollars going upgrade? honest question :-)\']',
#  ' ["both ato & every gov dept not staff training various mygov mgovid authentication programs databases."]',
#  " ['total crap! everything hinges code send. repeated attempts failed toget one.']",
#  ' ["i\'m looking mygov app. mygov id centrelink app neither give access mygov."]',
#  ' ["i difficulties multiple usernames mygov website (even gp466433).  change password allowing change password login saying there\'s error!  reset password yet again!  please suggest previous accounts expunged!  thanks."]',
#  ' ["the website hopeless not allow freedom choices. forces answers upon continues loop"]',
#  " ['because log process crap every time asked access account not accept passwords permantly loc ked fix b loody thing stop asking people access it']",
#  " ['uploaded documents 03/03/2021 not actioned']",
#  " ['did not check beta site  using feedback form cannot find way contact mygov without calling']",
#  " ['because system frozen va cant help basically system stuffed getting help offices line joke']",
#  " ['https://i.imgur.com/doxgape.png']",
#  " ['cant login']",
#  " ['spent 30 min making gov id  try log onto mygov says details wrong. fucking frustrated']",
#  " ['i received information assistance required']",
#  " ['i endless problems linking account ']",
#  " ['i didnt answer question no code sent email mobile ']",
#  " ['the system says 3 unread messages  however  cannot tell messages unread.']",
#  " ['i locked account made phone call told sorted problem could try twenty minutes waited till next day still wont let get passed password stage even though im using suggestion strong password create new account ']",
#  ' ["ca not log in"]',
#  " ['this worst site ever displeasure trying log into. still cannot log check messages!!! horrible!!']",
#  " ['gov ongoing joke']",
#  ' ["it\'s well designed. quite easy move around. really enjoy it."]',
#  ' [\'too convoluted "busy" main page\']',
#  " ['i simply went round round cirlces got nowhere. unhelpful routine ever encountered!']",
#  " ['because hard log  well nuisance anyway']",
#  " ['when u tell name wrong u complete fuck']",
#  " ['quite limited possible do']",
#  " ['fhfdg']",
#  ' ["same  not given info yet"]',
#  ' ["because trying save money crap online system not work bring back regular bas form posted save garbage"]',
#  " ['there no option say want opt jobseeker payment got permanent job. assume basic feature forcing enter money received multiple weeks confusion applying jobs satisfy requirements already one..']",
#  " ['i need see change actual options offered.  especially around childcare mutual obligations. ']",
#  " ['cant login ']",
#  " ['tasks need better explained!']",
#  " ['you cant offer answers pertaining neurologically damaged applicants.']",
#  " ['im struggle create account ']",
#  " ['read previous answer']",
#  ' [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  " ['as per previous answer']",
#  " ['you incredibly poor communicators. dont think even get mygov']",
#  ' ["i not fit box government trying squeeze us into."]',
#  " ['yes  im live share mom house 2 bedrooms. address 2 beevers st footscray vic 3011  1 month $500. yes  help mores money payment share moms thank much there.']",
#  " ['sign-in procedure difficult']",
#  " ['thank much ']",
#  " ['no way much  crap  wade through. ']",
#  " ['after successfully login account :  jk728811  screen displayed “  loading please wait upper address bar running many many “auth callback” code addresses 5 minutes  back !!!!   gone !   ']",
#  " ['shit site']",
#  ' ["obviously instructions not precice."]',
#  " ['well written easily understood ']",
#  " ['as true best knowledge ']",
#  " ['because always sticks']",
#  " ['agree']",
#  " ['i want apply new medicare care cant ']",
#  " ['helping bit accurately thanks ']",
#  ' [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  " ['both mygov mygov beta sites poor nil trouble shooting help']",
#  " ['i trying login centrelink via mygov without success.']",
#  ' ["i ca not get in"]',
#  " ['because no option add pay slip summaries employment income services . need email whereas could upload account update income asset section. also impossible see whole picture assets. disintegrated. worse website development ever']",
#  " ['repeat chat services stupid irrelevant not answer question!!!!!!!']",
#  " ['i felt informed']",
#  " ['despite lengthy format  eventually completed task. lengthy format made confusing.']",
#  " ['could see things use most']",
#  " ['see previous answer']",
#  " ['i could not access account old mobile number attached it.']",
#  " ['please delete mygov account: username: elvis.nguyen.zero@gmail.com']",
#  ' ["all wanted apply sickness benefits spent 3 days still not know right "]',
#  " ['information insufficient ']",
#  " ['locked site 2 hours']",
#  " ['not useful']",
#  " ['i use centrelink health sections available ']",
#  " ['possibly many steps']",
#  " ['no relevant circumstances need assist waiting answer ']",
#  " ['too centre link orientated']",
#  " ['i agreed information found relevant & circumstances']",
#  ' [\'the problem remains solved update issues faced simply trying login account. cannot login  services available  no matter well designed information  easily found  cannot used first place. not believe ever experience logging mygov occurred without issue  whether australia overseas. present  required set secure login password  serves almost no purpose always required enter code. beauty process code must either sent text message  \\\'generator app\\\'  course  phone. unhelpful don\\\'t access phone  not mention infuriating solution "i cannot access device/i lost device (i.e. app installed)"  "select receive sms". possible receive sms device not  fact not reason you\\\'re stuck first place?  accept 2021 need receive code addition password every single time login  code generator app sounds amazing! problem  doesn\\\'t work - see return scenario outlined  alternatively  you\\\'re overseas haven\\\'t lost device per se  still cannot receive sms: end result. back code generator app itself. managed use one  going process setting up. set app  to.... guessed - login! using sms receive code! hilarious considering setting precisely not use sms code  better hope remember set realise need (magic future telling powers required). manage foresight  somehow thought would save repeating nightmare circle dance logging mygov  think cracked it! however  trying use simple sounding login password + secret code generator app today  open app find without code. set scene: website simply says "enter code mygov code generator app. didn\\\'t get code? click send code via sms". app says  "about app: app generates codes enter sign mygov account. you\\\'ve set app  can..." oh  helpful. point options are: (1) request code via sms - cannot receive sms\\\'s overseas  course set app first place (refer first problem mentioned). (2) select \\\'continue\\\' app - beautiful thing. select continue takes process setting account. re-enter login details  useless password  hit submit.  says pure comedy gold: "your device already registered. please login remove device want set again". yes  that\\\'s right. app need use login telling need login use it. not need explain ridiculous is. course  remaining option call centerlink   alas  line hangs time get through. want finish tax return  all.  spending incredible amount money bring website content visuals user accessibility 21st century  please ensure users actually access traditional sense word - simply login. without basic functionality  site entirely useless. thanks advance! regards  tax payer.  \']',
#  " ['alwys look safty too']",
#  " ['only trying get access mygov. keep simple e.g car licence no']",
#  " ['when asked question sign answers given not applicable ']",
#  " ['you keep going round circles ']",
#  " ['i cant login. lot keep changing bloody process. ffs']",
#  " ['it not exist ']",
#  " ['because convinced sure helps me']",
#  " ['there no relevant no easy way navigate. ']",
#  ' ["i could not needed done."]',
#  ' ["you try cover possibilities without understanding doing"]',
#  " ['same last answer']",
#  " ['whoever framed survey obviously little understanding user requirements. question confusing appears no relevance specifics. perhaps use example would helpful.']",
#  " ['all false wont even let log wait 2 hours cause site garbage ']",
#  " ['all information require not file']",
#  " ['people helped me']",
#  " ['convoluted & confusing']",
#  " ['there no assistance particular difficulty']",
#  " ['because information incorrect ']",
#  " ['see previous']",
#  " ['found info not looking for']",
#  " ['n/a.']",
#  " ['as  need help genetic help offer']",
#  " ['great personalised information']",
#  " ['it true']",
#  " ['i included.']",
#  " ['it bit generic']",
#  " ['i need new password']",
#  " ['i click find login link']",
#  " ['limited online functionality forces call multiple occasions resolve matter coupled excessive hold times no call back service offered you']",
#  " ['no phone']",
#  " ['mygovid sucks']",
#  " ['because didnt want information. thought would able log centrelink easier  not']",
#  " ['it impossible log gov site']",
#  ' ["there minimal information  hard find bugs usually prevent loading it"]',
#  " ['my answer']",
#  " ['no']",
#  " ['maybe ']",
#  " ['wrong information not helpful ']",
#  " ['less paper work ']",
#  " ['the questions suggested pension card not yet have.  no provision entering alternative information enable login']",
#  " ['system useless']",
#  " ['crashes time']",
#  " ['the information found relevant needed know.']",
#  " ['lnp propaganda make legal benefits difficult receive']",
#  " ['payment information date useful show type payment page ']",
#  " ['i made comment no feedback.']",
#  " ['see previous response ']",
#  " ['your apps logins trash ']",
#  " ['as stated previous response  service looking  centrelink service  not page.']",
#  " ['cannot link medicare attempted numerous times page keeps returning original screen not going next']",
#  " ['my pervious answer  could not get on']",
#  " ['unable access information ']",
#  " ['legislation wasnt put laymans terms inform rights obligation australian citizen ']",
#  " ['xyz']",
#  " ['            \\xa0                                                   .']",
#  " ['he site maintainance information extent not avaiable logged in. no information lenght delay.']",
#  " ['not straight forward ']",
#  " ['same answer previous ']",
#  " ['nil']",
#  " ['as per previous statement. ']",
#  " ['i cannot sign gov telling wrong thing']",
#  " ['it job ndis ']",
#  " ['your app worthless uselesscrap worse last pathic efforts scamming fo govt dollar ']",
#  " ['same service works fine area']",
#  " ['same first answer']",
#  " ['i didnt find info.']",
#  ' ["i want create new account code not sent  wasting time"]',
#  " ['your website overloaded deliberately confusing']",
#  ' [\'it waste time. ask question some"virtual" machine gives rubbish answer. taxpayer it\\\'s not good enough. use human please\']',
#  " ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  " ['the system not working hard use ']",
#  " ['liked']",
#  " ['as above']",
#  ' ["because not get wanted"]',
#  " ['who writes things']",
#  " ['no reason']",
#  " ['because not work']",
#  " ['strongly disagree ']",
#  " ['no help all']",
#  ' ["i could not find information "]',
#  " ['not relevant all']",
#  " ['i log mygov things  read messages  make medicare claims  etc. current site seems like unstructured list informational pages not want.']",
#  " ['their nothing starting maintaining small business']",
#  ' ["no good married woman asked give birth certificate details told not match no options"]',
#  ' ["still ca not access site  no matter option select"]',
#  " ['i click centerlink old website linked services']",
#  " ['i called overseas international call hang centrelink officer. called expensive cost?']",
#  " ['was unable find information due system glitch']",
#  " ['hello. locking account gov']",
#  " ['cannot get discuss no provision callback email assist']",
#  ' ["could not login - stop hiring software developers  start upgrading hardware. cannot run shit servers 90\'s"]',
#  " ['the information relevant not accessible ']",
#  " ['because believe ']",
#  " ['as usually logging mygov due wanting perform required tasks  found tasks home page streamlined experience.']",
#  ' ["that\'s feel"]',
#  " ['data ok presentation format poor.']",
#  " ['unable access']",
#  " ['there clear feedback enquire progressed  took searching confirm query']",
#  " ['the system stalled early stage.']",
#  " ['unable find information could not log site']",
#  " ['get real listen customers  nerds put pages not user friendly']",
#  " ['eat shit']",
#  " ['accurate']",
#  " ['i\\\\the form joining gov security refused accept genuine passwords fulfilling criteria.']",
#  " ['you change password random threaten permanently bar use it']",
#  " ['i told you']",
#  " ['i told before.']",
#  " ['see previous']",
#  " ['you cant log create account dont email address']",
#  " ['provides easy ness claim online.']",
#  " ['unsatisfactory']",
#  " ['its no good']",
#  " ['info assisted helping start account']",
#  " ['still cannot access account know details stupid app']",
#  " ['trying get hopeless']",
#  " ['the help desk number not available.']",
#  " ['sucks']",
#  " ['need find better ways change passwords forgotten dont phone']",
#  " ['why u lock people website ']",
#  " ['useledd']",
#  " ['why not???????? cannot access anythinhg till get details']",
#  " ['i not get information']",
#  " ['i keep going around circles  logging mygov  getting no sign achieved anything']",
#  " ['can not get information ']",
#  " ['unable login dont get codes sent me']",
#  " ['totally confused']",
#  ' ["i could not find information needed"]',
#  ' ["i looking child support payment information not live beta yet."]',
#  " ['ytryr']",
#  " ['easy']",
#  " ['i not look information  reporting']",
#  " ['mygov doesnt seem personalised currently disjointed ']",
#  " ['it sent loop doesnt work']",
#  " ['my circumstances limited eligible age pension  nothing age pension site']",
#  " ['i professional engineer working designing human interface solutions. mygov breaks many guidelines rules  good design. logged today access mygov message.  would not display message. content many mygov messages not particularly private could included personal email  thereby avoiding pain intimidation logging mygov together.']",
#  " ['????']",
#  " ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  " ['was relevent search']",
#  " ['because not sign account. twice successfully managed sign in. tried using “forgotten username “ never receive email even though email address otherwise would not receive mail telling messages! ']",
#  " ['i believe information ambiguous make it. ']",
#  ' [\'the onliune process not fully supported manual intervention ie:" keeping records date \']',
#  ' ["it\'s not user friendly older persons"]',
#  " ['because information confusing & isnt helping ever.']",
#  " ['it seems current mygov']",
#  " ['no comment']",
#  " ['see last comment.']",
#  " ['not answering question ']",
#  " ['this information found production version mygov ato  centrelink....so course relevant ! otehr information asking about?']",
#  " ['gov staff not trained computer science.']",
#  ' ["did not work"]',
#  " ['how connect mygov?']",
#  " ['online updated information seems get lost not actioned']",
#  " ['see previous answer']",
#  " ['because no help no one cares']",
#  ' [\'"you one task do" ... could not today. report income. wasting people\\\'s time. income today tomorrow not change. write systemic procedural problem  not website one. guess what? one end users!\']',
#  " ['cant login']",
#  " ['all information relevant situation assisred me']",
#  " ['its account l need link gov']",
#  " ['you didnt answer question ']",
#  " ['i cant achieve want ']",
#  " ['unable lig using phone']",
#  " ['impossible log in!']",
#  " ['gov ongoing joke']",
#  " ['nothing relevant ']",
#  ' ["did not really find anything useful go through"]',
#  " ['m']",
#  " ['same before']",
#  " ['i think seemingly confusing conflicting information offered.  ']",
#  " ['cant login ']",
#  " ['you hate disabled people']",
#  " ['not ']",
#  " ['it incorrect']",
#  ' [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  " ['it not easy update assets.']",
#  ' ["the first time reported new system confusing ca not report all"]',
#  " ['information didnt work']",
#  ' ["unable access information looking for... not guys employ unemployed qualified jobseekers? plenty... know (with fantastic systems)"]',
#  ' ["ato reques\'d feedback. kept returned \'the info. found etc\' page input could not sent"]',
#  " ['thank much ']",
#  " ['there icons services  may select not sure works']",
#  " ['absolutely no information help']",
#  " ['when followed access denied.']",
#  " ['i understood everything presented']",
#  " ['because neither agree disagree']",
#  " ['very good']",
#  " ['yes please thanks ']",
#  ' [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  " ['no particular reason.']",
#  ' ["despite repeatedly signing correctly  including changing password said wrong (it not) waiting 2 hours try facing another 2 hours try then... beta site failure"]',
#  " ['much harder account. services complicated use website']",
#  " ['repeat previous statement']",
#  " ['i would liked details type paymsnt recieved ']",
#  ' ["due information multiple pages (before easily attained processed one page) jumble presentation."]',
#  " ['i found no information']",
#  " ['i didnt search information able access inbox']",
#  " ['i could not access account old mobile number attached it.']",
#  " ['please delete mygov account elvis.nguyen.zero@gmail.com']",
#  " ['like said totally confused superanuation companies not much help finding information wanted ']",
#  " ['locked 2 hours']",
#  " ['the options available clear understand']",
#  " ['the information needs ']",
#  " ['yes  generally clearly articulated']",
#  " ['i agree  information found easy understand']",
#  " ['test']",
#  " ['very nice exces understand ']",
#  " ['my question not answered']",
#  " ['useful explanation points']",
#  " ['same ']",
#  " ['cant access it']",
#  " ['it not exist']",
#  " ['really  get well']",
#  " ['it easy understand completely unhelpful. ']",
#  ' ["the information not helpful finish reporting."]',
#  " ['again.. circuitous ambiguous']",
#  " ['in case  iwhat seeking straight forward request  however black menu bar centrelink mygov website  five items black menu bar  could possibly contain answer leaving traverse entire website answer. ']",
#  " ['what information referring too??????? issue centrelink reporting format made longer  unnecessary steps.']",
#  " ['cant even access anything trash site ']",
#  " ['once know get information easy understand']",
#  " ['confusing']",
#  " ['not helpful']",
#  " ['because couldnt solve question ']",
#  " ['it confusing']",
#  " ['see previous']",
# ...
#  ' ["because not know going on. site not work. believe things secure??"]',
#  " ['nooooooo  voice recognistion  noooooo stop pushing rubbish!!!!!!   politicians get crap  ']",
#  " ['all changes must mean apps arnt secure']",
#  " ['the two gactor authentication makes feel secure login details ']",
#  ' ["i\'m optimistic dept. :-)"]',
#  " ['i used mygovid ']",
#  " ['mygov relies two factor authentication using sms. sms not secure. option use totp authenticators  services accessed overseas  without access australian mobile number.']",
#  " ['i could not access account old mobile number attached it.']",
#  " ['its safe provide mygov application use phone helpful ']",
#  " ['forced use mobile phone  unsubsidized expense coercion blackmail. please delete account: username: elvis.nguyen.zero@gmail.com']",
#  " ['we find future government department not got good record ']",
#  " ['locked 2 hours not get on']",
#  " ['i trust government departments keep info safe']",
#  " ['seems secure far']",
#  " ['i never feel safe site online time ']",
#  " ['i like 2 factor authentication. prefer not using biometrics (eg voice print per phone service)']",
#  " ['i agreed fact felt safe & secure using mygov beta']",
#  " ['hello']",
#  " ['to technolical advantage use protect ']",
#  " ['i could not sign out']",
#  ' ["well  hope secure"]',
#  " ['what gov beta?']",
#  " ['its safe no bastard get ']",
#  ' ["fuck no not "]',
#  " ['because really feel safe comfortable using gov']",
#  " ['i no way knowing.  no way verifying site - even login could pretending mygov harvesting credentials.  needs way greeted information mygov knows user not entered user login. ']",
#  ' ["i ca not say anything program yet."]',
#  " ['have no confidence security interest.']",
#  " ['how website leave feeling anything? either works provide information (in case not)  not.']",
#  " ['what ???? safe secure?????? complaint digital id tried log 10 times without success.']",
#  " ['because security top notch']",
#  " ['humans assisted me']",
#  " ['doubt whether system really secure ']",
#  " ['definitely not']",
#  " ['feel?']",
#  ' ["if ca not find info sure others ca not also"]',
#  " ['n/a.']",
#  " ['cant log cant get point feeling safe']",
#  " ['i wont share']",
#  " ['feel uneasy giving opinion ']",
#  ' ["was not able login check security felt comfortable"]',
#  " ['i zero trust faith mygov now... well max employment(joke century) centrelink. max calked (appointment) hng uo putting phone loudspeaker...now instantly   suspended   again...']",
#  " ['because no worries all']",
#  ' ["government australia terrible history data security  no reason believe safer here"]',
#  " ['no']",
#  " ['who knows whos im web couldnt login ']",
#  " ['in good hands ']",
#  ' ["i not know enough application."]',
#  ' ["i ca not access anything!"]',
#  " ['i go office ever health problems']",
#  " ['easy anyone hack']",
#  " ['i believe using site safe.']",
#  " ['i never use unless get printout wipe with']",
#  " ['same original mygov website']",
#  " ['see previous response ']",
#  " ['i dont trust info anyone']",
#  " ['your apps logins trash ']",
#  " ['could not use']",
#  ' ["yes could not accessanything "]',
#  ' ["this country gives data away  5 eyed alliance creating criminals poor jurisprudential authorty"]',
#  " ['have not tested yet']",
#  " ['see answer 1 2 3']",
#  " ['very frustrated']",
#  " ['if cant link data secure databases would trust personal information. ']",
#  ' ["you rely much mobile phone numbers.  change endure long wait phone get sign changed. ca not make reliable email least make changes accessible us?"]',
#  ' ["if fo not correct information  coukd possibly ferl safe.  must realise know mothers grandmother\'s maiden names use secret questions.  yet  gov tell zi wrong   sm sorry  wrong."]',
#  " ['same before']",
#  " ['it password ']",
#  " ['while gov secure lose phone number deleted code gen app im forced deleted whole gov account start  rather answering secret questions not even gov phone line update details!!']",
#  ' ["if ca not trust gov  trust"]',
#  " ['because hack choose not  im good person. also choose not hack bank add zeros balance. build pathetic little 15mhz computer doesnt ability leave online tracks. leave cant know already once. know current nsa password know intend changing next  dont believe know going change yet! lmao! (change theory guys  autistic people see answers!;) . no one ever really safe online! fact.']",
#  ' [\'have laugh one makes thinking swaddling baby  plus no one feel safe n secure days cant even afford buy scripts. wld feeling "safe n secure"\']',
#  " ['it deliberately designed deter people using it.']",
#  " ['another machine! another frustration!!!!']",
#  " ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  " ['the system doesnt work ']",
#  " ['true']",
#  " ['again  not issue  trying find simple answer']",
#  " ['do twist arm identity id  no way']",
#  " ['no reason']",
#  " ['strongly agree ']",
#  " ['i home']",
#  " ['no im upset centerlink people said going easy ..your joking .i need go back sort face face ']",
#  " ['the website seems less official gov websites']",
#  " ['i feel frustrated ']",
#  " ['did not get anywhere system']",
#  " ['no solutions offered']",
#  " ['huge online data bases get hacked time']",
#  " ['was unable access  system locked out']",
#  " ['it irrelevant cannot get stay connected!']",
#  " ['could not login']",
#  " ['a modern responsive interface gives impression website looked us security data.']",
#  " ['the beta site incomplete']",
#  " ['good']",
#  " ['superficial security good  ....']",
#  " ['i cannot tell secure would be. not seem sensible perhaps not secure.']",
#  " ['unable use it']",
#  " ['it not user friendly ']",
#  " ['no']",
#  " ['true']",
#  " ['no fallback positionj help phone number']",
#  " ['you change password random threaten permanently bar use it']",
#  " ['.']",
#  " ['two factor authentication works well']",
#  " ['nobody get details safe- reason couldnt enter them']",
#  " ['my pin sign on/off mine unless compromised.']",
#  " ['yes  little secure since whole gov deleted due phone number chnaged ']",
#  " ['tell team not tell rebuild account....stupid info']",
#  ' ["the page l could get  could not get mygov all"]',
#  " ['what point question?']",
#  " ['rather old way centrelink']",
#  " ['did not get anything.']",
#  " ['cant even log in. takes almost 30min secure code arrive.']",
#  " ['why would anyone take trouble - nothing see here']",
#  " ['keeps blocking ']",
#  " ['cant get account  doesnt send codes  staff cant reset']",
#  ' ["did not work guess still secure"]',
#  " ['safe guards']",
#  " ['the website doesnt feel secure authenticated app - ie webpage could anything. make similar secure bank apps ']",
#  " ['it sent loop ']",
#  " ['i trust every government site']",
#  " ['it feels like designed committee focused security fulfilling basic function simplest easiest way']",
#  " ['i want give feedback only']",
#  " ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  " ['yes feel safe']",
#  ' ["my answers probably wo not make difference."]',
#  " ['safe cyber crime not centrelink bias ']",
#  " ['too difficult']",
#  " ['i dont feel safe using type servey havnt successful elsewhere  never feel safe using mygov.']",
#  " ['the ui mygov beta harder navigate - apart new dashboard old mygov easier use navigate.']",
#  " ['not sure']",
#  " ['see last comment.']",
#  " ['i trusting is']",
#  " ['i concerns dta privacy security leaks hacks system vulnerabilities due bad coding poor testing thats current system. think gov generally poor security general.']",
#  " ['this authentication going backwards & making every user vulnerable.']",
#  " ['rubbish']",
#  " ['nothing online really safe.']",
#  " ['i want able access laptop ease']",
#  ' ["afaik see no details strong  weak  encryption setup is. https nothing without strong implementation  across sites make users sidelogin jump around  whilst trying plaster cracks make \'unified\' website still-disparate  double-handling  invariably separated increasingly irrelevant  ancient gov dept silos (centrelink  ato  etc)."]',
#  " ['cant login']",
#  " ['ease use']",
#  " ['hardly used ']",
#  " ['i dont think online platform reliable ']",
#  " ['i no trouble previous system dont see changed causing stress']",
#  " ['still cant log mygov!']",
#  " ['gov ongoing joke']",
#  " ['nothing concerning note']",
#  " ['no']",
#  " ['your kidding right']",
#  " ['no. want give feedback  no option  agree policy sharing data outside company. way survey giving information government not third parties.']",
#  " ['i friend whose information illegally accessed sold government employees. no system infallible. however id like see automatic 2 year jail term applies access information illegally criminal purposes even ‘only helping mate.  no matter government system.  ']",
#  " ['ridiculous ']",
#  " ['youre private company. profit neglected.']",
#  " ['read previous andwer']",
#  ' [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  ' ["i not know does."]',
#  " ['as per previous answer']",
#  " ['if cant operate program  trusted ...could trustef']",
#  " ['robodebt  hacking australian systems... please. whole continent gone hill government']",
#  " ['thank much ']",
#  " ['may be']",
#  " ['givernment generally useless keeping things private']",
#  " ['mygov beta provided information made feel privacy secure']",
#  " ['who knows?']",
#  " ['very good']",
#  " ['very helpful framework consistently constant ']",
#  " ['experience today changed opinion']",
#  " ['well hope safe']",
#  " ['big brother joke ']",
#  " ['pfft']",
#  " ['the two favor authentication makes feel secure login details ']",
#  " ['…unless really goes downhill  hopefully important standards monitored  place ongoing.']",
#  ' ["i could not access account old mobile number attached it. not know received security code not confident information secure. "]',
#  " ['nope']",
#  " ['we see']",
#  " ['no faith ']",
#  " ['could not even see details ']",
#  " ['hopefully technology government departments use secure']",
#  " ['because info & steps quite hard fake!']",
#  " ['i not trust mygov beta protect privacy times not monitoring process site ']",
#  " ['until hackers get in.']",
#  ' ["mygov lot personal information. bank statements  investment records  etc. i\'d prefer not much personal info one agency."]',
#  " ['i agreed trusting mygov beta  protecting privacy & security']",
#  " ['it undercontrol govt australia']",
#  " ['there always hackers']",
#  " ['this getting waist time ']",
#  " ['yep. not even access it. ']",
#  " ['it true cove trustworthy respectful']",
#  " ['who knows -https://dta.syd1.qualtrics.com/jfe/form/sv_e9bkxymmpm12iy9 could scam. user no option trus you.']",
#  " ['i trust mygov protect personal information.']",
#  " ['i no reason believe  either']",
#  " ['i not even know mygov beta  trial feedback line. ']",
#  ' ["no idea checks balances ca not comment."]',
#  " ['i ex government employee . know security']",
#  " ['too many people much access']",
#  " ['no confidence']",
#  " ['trust government?  hahahah']",
#  " ['seems secure']",
#  " ['n/a.']",
#  " ['this site hard use']",
#  " ['i trust it']",
#  " ['the government pretty trustworthy.']",
#  " ['too many terms conditions forms click through']",
#  ' ["do not know running behind ensure site secure"]',
#  " ['suspect prone overseas hack']",
#  " ['already answered']",
#  " ['they think would look security ']",
#  " ['statistically likely data breach. government consistently downplays implications ruin lives']",
#  " ['no']",
#  " ['so far cant trust telling something falls couldnt perform task told ']",
#  ' ["i\'m sure previous experience "]',
#  ' ["i not know enough security site."]',
#  " ['i cannot access anything!']",
#  " ['useless nothing']",
#  " ['security  security !!   personal information easy hack']",
#  " ['there always concerns accessing websites.']",
#  ' ["stupid idea giving private firms people\'s personal data. not access"]',
#  " ['being beta not confident full website']",
#  " ['see previous response ']",
#  " ['your apps logins trash ']",
#  " ['i cannot even link account must secure!']",
#  " ['i suppose nobody else access cannot']",
#  " ['no blockchain  trust much open source replicatesd peer reviewed laboratory experiment']",
#  " ['as before']",
#  " ['see answers 1 2 3']",
#  " ['its secure cannot access no use me']",
#  " ['data security obviously issue mygov app website. ']",
#  " ['hiw trust gov cannot get information correct !!!']",
#  " ['it easy ']",
#  " ['easy']",
#  " ['yes security accounts good not even get account (allow option get in)']",
#  ' ["why not i"]',
#  " ['read previous response!!!! yahoo serious? mean... serious guys?']",
#  " ['thats difficult one.it shld trust u protect life n trust no one']",
#  " ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  " ['the web site terrible use ']",
#  " ['true']",
#  " ['assume would']",
#  " ['you leaked information former employer not relevant information well. no answer']",
#  ' ["what\'s stupid fucking questions?"]',
#  " ['strongly agree ']",
#  " ['imshared no privacu system frustratingly unhelpful']",
#  " ['you cant even find email address ive using years.. always invalid']",
#  ' ["gov websites history problems regard. changing visual design wo not change track record."]',
#  " ['the last online census']",
#  " ['should able get information linked services']",
#  " ['no help given']",
#  " ['i agree would attempt so']",
#  " ['i trust privacy security protected. ']",
#  " ['cyber security not 100% ']",
#  " ['if cannot get  suppose privacy protected!']",
#  " ['could not login']",
#  " ['i find sign mygovid quite disregarded low hidden sign page  comfortable way login.']",
#  " ['i dont judge.']",
#  " ['see previous']",
#  " ['to extent  confidence govt records secure.']",
#  " ['cant login cant achieved protect information']",
#  " ['read previous text ']",
#  " ['no']",
#  " ['true']",
#  ' ["it\'s impossible access site anyway"]',
#  " ['two factor authentication']",
#  " ['the government allowed keep pin  sign on/off confidential.']",
#  " ['i no doubt keep safe']",
#  " ['great privacy cant open account']",
#  ' ["why reason not?"]',
#  " ['dont belueve shit']",
#  " ['hopeless']",
#  " ['can never get see']",
#  " ['ask many personal questions']",
#  ' ["do not trust government look interests "]',
#  " ['it gov regards privacy security guess.']",
#  " ['priof']",
#  " ['i agree privacy policy says data may go overseas unnecessary close option make secure australians ']",
#  " ['it sent loop']",
#  " ['i trust official sites aust governments reputable businesses.']",
#  " ['anything looks like designed committee cannot fully secure private']",
#  " ['no idea']",
#  " ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  " ['i trust website']",
#  " ['it must safe even cant access it.']",
#  " ['most politicians corrupt days.']",
#  " ['pretty safe']",
#  ' ["could not use "]',
#  " ['no dont trust anything government more.']",
#  " ['the ui mygov beta harder navigate - apart new dashboard old mygov easier use navigate.']",
#  " ['not sure']",
#  " ['see last comment.']",
#  " ['i believe so']",
#  " ['i concerns dta privacy security leaks hacks system vulnerabilities due bad coding poor testing thats current system. think gov generally poor security general.']",
#  ' ["no user trust government staff not even understand security protocols."]',
#  ...]

# %%
def clean_up(data):
    return_data = []
    for line in data:
        new_line = ""
        for word in line.split(" "):
            if "\n" in word:
                new_word = word.replace("\n"," ")
            else:
                new_word = word
            new_line = new_line + " " + new_word
        return_data.append(new_line)
    return return_data

# %%
import nltk

text = clean_up(data)
all_string = ''
for sentences in text:
    sentences = sentences.replace("[","")
    sentences = sentences.replace("]","")
    sentences = sentences.replace("\'","")
    sentences = sentences.replace("!","")
    sentences = sentences.replace("\\","")
    all_string = all_string + sentences

text
# Out:
# ['  ["i not provided info yet"]',
#  "  ['not able access ato site complete basic reporting  pathetic waste time.repeatedly denied access shut   .. truly waste time utter garbag!!! someone fet paid  taxpayers money put crap together joke  think people hours waste trying sort shit out??!! stipped sending bas forms? dont want paet lame malfunctioning computer system ! regulwr paper bas forms remove worthless shit computer system!!e!!']",
#  '  ["the operator great i\'d code pkr040"]',
#  "  ['as initiatives  concerns not handle technology well ']",
#  "  ['cant login ']",
#  "  ['information requests keep piling due date!']",
#  "  ['i writing behalf partner parkinsons disease. according ndis must access centrelink himself. neurological problems make difficult. frozen account three times. trying open another new account  site wont allow this. easier way/']",
#  "  ['seems except layout first glance']",
#  "  ['im trying create account months always come back wrong attempts im lock ']",
#  "  ['due fact gov login page locked account putting password correctly. ask question online chat took circles incorrect information answers']",
#  '  ["i not looking particular information  curious website looked like."]',
#  "  ['i recently updated information assets centrelink found new site much harder use previous layout complex not enough space one box enter bank account numbers.']",
#  "  ['i cant access mygov website overseas dont mobile phone linked mygov back australia. would helpful able use mygov id log mygov without link mygov id mygov account within mygov. ']",
#  '  ["it\'s limited options  rather providing full access every department. seems suggest options  not let anything else. hardly features  ca not really evaluated."]',
#  "  ['i could access need easily ']",
#  "  ['i previously able get gov. todays experience nightmare sent around circles. poor communications - loads words instructions dont go anywhere. ']",
#  "  ['nothing easy find. no information specific.']",
#  "  ['me insider hospital metals clinic footscray renew outside no money value. help thanks much.']",
#  "  ['cunts frauds hacked ']",
#  "  ['signjng- difficult. ']",
#  "  ['thank much ']",
#  "  ['theres no reason ']",
#  "  ['deadset useless cunts yous ']",
#  "  ['the  beauracratic brains  behind website   less  useful. ']",
#  "  ['i thought feedback form! password criteria bullshit. log onto mygov year tax impossible remember password account permanently locked!!!!! painful']",
#  '  ["i\'m trouble getting gov activate ndis code "]',
#  "  ['after successfully login account :  jk728811  screen displayed “  loading please wait upper address bar running many many “auth callback” code addresses 5 minutes  back !!!!   gone !   ']",
#  '  ["because ca not log in. mobile number different phone wo not generate code"]',
#  "  ['tried create account without success. cannot access account']",
#  "  ['easily understood ']",
#  "  ['because trouble pass word. keeps blocking fear security']",
#  "  ['some one hacking personal  gov details removing  teleohone address replaging own. believe itis coming 7 chesterfield drive wyndham  vale female relative visiting driving car must false licence no gp would let herdrive.she hardly walk looks 100 years old.']",
#  "  ['no explanation shut out']",
#  "  ['too much']",
#  "  [' ']",
#  "  ['the information found helpful. page right?']",
#  "  ['detailed']",
#  "  ['the centrelink income stream update unusable -it asks amount commutation not made not take 0 answer']",
#  "  ['good']",
#  "  ['i saw fro log site']",
#  "  ['i sees things actually designed like ']",
#  '  [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  "  ['there no trouble shooting help page.']",
#  "  ['i trying contact mygov problem encountered recently.']",
#  "  ['it somewhat helpful. website keeps jumping back sign page  frustrating']",
#  "  ['switching account services made use website much harder less user friendly']",
#  "  ['your stupid line chat service not answer questions? waste time energy!!!!!']",
#  "  ['everytime update change app  nothing issues. stop updates buy updated phone']",
#  "  ['i found need easily ']",
#  "  ['was really easy find everything looking for']",
#  '  ["the \'update assets\' sections much better (less lengthier point/all one page) original version. new area requires constant clicking new fields submission.  "]',
#  "  ['saw helpful things easily like tasks  payments services']",
#  "  ['i looking get csa  could not find it. could find could apply new assessment  not wanted.']",
#  "  ['i wanted access mygov inbox. able to']",
#  "  ['your website fucked!locked entered correct info password questions ']",
#  "  ['inbox messages not clearly visible. tax information not visible.']",
#  "  ['i could not access account old mobile number attached it.']",
#  "  ['may please delete mygov account. username: elvis.nguyen.zero@gmail.com']",
#  "  ['totally confused not understanding many questions site wanted log login get another text log in']",
#  "  ['its nightmare start et able finush']",
#  "  ['could not get app locked 2 hours said get app gave wrong answer ']",
#  "  ['not useful']",
#  "  ['eaiser understand']",
#  "  ['just difficult many steps']",
#  "  ['there no response;to complain ']",
#  "  ['i make phone call try sort problem still no access account.']",
#  '  [\'the stock images dominate page much mind. like "jump topic" section\']',
#  "  ['using mygovid app useless']",
#  "  ['i agreed fact  information found helpful.']",
#  '  [\'the problem remains solved update issues faced simply trying login account. cannot login  services available  no matter well designed information  easily found  cannot used first place. not believe ever experience logging mygov occurred without issue  whether australia overseas. present  required set secure login password  serves almost no purpose always required enter code. beauty process code must either sent text message  \\\'generator app\\\'  course  phone. unhelpful don\\\'t access phone  not mention infuriating solution "i cannot access device/i lost device (i.e. app installed)"  "select receive sms". possible receive sms device not  fact not reason you\\\'re stuck first place?  accept 2021 need receive code addition password every single time login  code generator app sounds amazing! problem  doesn\\\'t work - see return scenario outlined  alternatively  you\\\'re overseas haven\\\'t lost device per se  still cannot receive sms: end result. back code generator app itself. managed use one  going process setting up. set app  to.... guessed - login! using sms receive code! hilarious considering setting precisely not use sms code  better hope remember set realise need (magic future telling powers required). manage foresight  somehow thought would save repeating nightmare circle dance logging mygov  think cracked it! however  trying use simple sounding login password + secret code generator app today  open app find without code. set scene: website simply says "enter code mygov code generator app. didn\\\'t get code? click send code via sms". app says  "about app: app generates codes enter sign mygov account. you\\\'ve set app  can..." oh  helpful. point options are: (1) request code via sms - cannot receive sms\\\'s overseas  course set app first place (refer first problem mentioned). (2) select \\\'continue\\\' app - beautiful thing. select continue takes process setting account. re-enter login details  useless password  hit submit.  says pure comedy gold: "your device already registered. please login remove device want set again". yes  that\\\'s right. app need use login telling need login use it. not need explain ridiculous is. course  remaining option call centerlink   alas  line hangs time get through. want finish tax return  all.  spending incredible amount money bring website content visuals user accessibility 21st century  please ensure users actually access traditional sense word - simply login. without basic functionality  site entirely useless. thanks advance! regards  tax payer.  \']',
#  "  ['its seems high level safty']",
#  "  ['non']",
#  "  ['too complex  especially older australians. seems worked clever ways exclude. e.g ahange phones.']",
#  "  ['i able read notice inbox unable sign site']",
#  "  ['i unable update address - tried many times.  asked provide proof birth dropdown options no option proof birth - children listed. uploaded information messaged provide proof birth. upload one  kids names still no option dropdown upload birth certificate. hugely frustrating started claim 30/12/20. cant get thru phones either boxwhen asked provide information']",
#  "  ['why keep asking email address password?']",
#  "  ['because hoops making jump thru login ridiculous. code generator doesnt work whole process sends circles. bloody ridiculous ']",
#  '  ["there not anything could help"]',
#  "  ['i spoke rude disinterested young female clearly not suffient training regarding email release whi asked anything else hung befire could reply....what heck wrong people....the previous man spoke amazingly courteous.....please call back explain....0421968108  debbie breen.']",
#  "  [' expresses clear true ']",
#  "  ['the new site appears triumph design practicality.  hard find information- using phone tablet image tiles big no indication scrolling required- not far options user is. could not find centrelink assume not there. options task based no easily visible information go none options seemed cover wanted do. ']",
#  "  ['i many issues using latest update report employment income.']",
#  "  ['the whole thing ambiguous circuitous']",
#  '  ["as member community housing provider (affiliated housing sa)  required twice yearly provide income information external housing provider called common equity. common equity requested contact centrelink request \'statement income\' centrelink end last financial year order assess rent payable. upon time stated senior centrelink  information readily available provided. no longer case  could mean tenant public housing  may well end paying full ceiling rent not provided sufficient documentation income. centrelink withdrawn access summary end financial year income statements accessible printable?"]',
#  '  ["your beta version govid process medicare claims painful exercise  simplify authentication process authentication instead rubbish mygov code  whole via not working. i\'m definitely never going use app again! "]',
#  "  ['from years experience. ']",
#  "  ['too many steps arrive point. much reading. much repetition. must extremely difficult non english speakers. old system centrelink reporting far user friendly!!']",
#  "  ['the site bad  clunky trying link accounts nightmare 12 year old could design better website ']",
#  "  ['not everything require file']",
#  "  ['because interaction stress free.']",
#  "  ['convoluted confusing']",
#  "  ['nothing provided assisted problem']",
#  '  ["ive beentrying update bank details went video updating details not icon menu tbe video mentioned trying update finding solution"]',
#  '  ["ask password not sent come usaying sent not "]',
#  "  ['some confusing']",
#  '  ["i trying complete grant application (tourism support) services australia.  need ato tax certificate.  trying penetrate ato website instructions certificate almost impossible (and commercial lawyer 30 years experience).  however absurd thing (and mygov relevance) ultimately certificate generated paper sent post !  surely commonwealth government claims trying things digitally  still operating system offocial documents sent post [snail mail...] current mygov account holders ridiculous!  noticed no improvements cutting government bureaucracy red tape past 25 years  despite rhetoric!.  need design implement world\'s best practice systems.  sending pieces paper letterboxes 2021 not meet description!"]',
#  "  ['my details not changed get report']",
#  "  ['very helpful']",
#  "  ['couldny find ct scan information self even though done couple weeks ago']",
#  "  ['n/a.']",
#  "  ['not getting code link email phone']",
#  "  ['i need speak someone  system loop cant get help need']",
#  "  ['integration good idea']",
#  "  ['because information was']",
#  "  ['i didnt notice new information ']",
#  "  ['my problem centrelink site']",
#  "  ['it info ive seen previously tried put better way']",
#  "  ['cant use forgot password tab']",
#  "  ['i looking login screen  used seeing.  going remove  understand  would like suggest putting quick link top right bottom amongst links.  whilst site informative people want get get need assist them.  believe site must address lower level user knowledge.  otherwise leaving sued olympic committee australian olympics. ']",
#  '  [\'because "secret questions" aleays wrong accound keeps loccking\']',
#  "  ['centre link supposed linked my.gov yet put information again. drop boxes not relate asked download. incredibly cumbersome. information asked pointless. someone already stress making ill bring navigate 3 university degrees.']",
#  "  ['limited online functionality forces call multiple occasions resolve matter coupled excessive hold times no call back service offered you']",
#  "  ['can not access gov no phone access']",
#  '  ["i changed (i thought) going easier time logging mygov  using strongly recommented mygovid???????  joke  cannot login either   great job!!!!!! due  cannot access max...so got cut centrelink  again...suspended automatically max... beg get put back on.. mygovid total joke  better hope information not get hacked... i\'ve read article   finishing setting new mygov.  mygov not recognise passwords...old new one mygovid. great jobs guys  whoever developed dismissed immediately. no doubt suspended  cutoff centrelink   again"]',
#  "  ['i dont see use all. go round round dont seem get anywhere. ive no idea use mygovid is. still log centrelink seperately']",
#  "  ['this site useless']",
#  "  ['because forgot password  code never sent email address mobile. secret questions seemed not available']",
#  "  ['either info incorrect site bugged']",
#  "  ['my answer']",
#  "  ['i havi g trouble wirh website']",
#  "  ['i think ']",
#  "  ['because says change phone number account settings login select account tried keep getting code sent phone number dont number moment head im not good ']",
#  "  ['easy get information ']",
#  "  ['because want simple change address area/position website']",
#  '  [\'i unable easily look balances mygov holds accounts.  need go "updates" see  even not wish change balances.\']',
#  "  ['because helpful ']",
#  '  ["the digital voice could not recognise voice properly letter end numerals continually repeated information became frustrated."]',
#  '  ["i unable sign-up centrelink using phone worse app sign told current affair horrible  experience get work better!"]',
#  "  ['i cant link medicare. mygov ask step step process type medicare card details enter  type name dob enter  type address enter. asked details doesnt match doesnt go next stage.  user doesnt know one not correct.']",
#  "  ['absolutely worst app ever used']",
#  "  ['i easily found information looking for.']",
#  "  ['it ok introduction']",
#  "  ['another private firm given private information get rich exploiting disadvantaged help liberals destroy social security. shame making life harder poverty']",
#  "  ['very easy follow page layout']",
#  "  ['when contacted centalink complaints found quite difficult.  tried call back once. position unable take call. no callback number call come private number.']",
#  "  ['i denied job seekers  claim didnot complete jobseekers snap shot. jobseekers app no clear instuctions complete kobseekers snapshot']",
#  "  ['i live outside australia not easy make call. help services extremely user unfriendly. systems backwards say least. desperate need assistance yet design services least assistance. craig upjohn +66928255579']",
#  "  ['your apps logins useless  trash']",
#  '  ["i understand trialling page centrelink services.  no easy way find page  case scroll  scroll  scroll see  even centrelink service not anyway.  sort menu  allowing pick service would much useful."]',
#  "  ['attempted numerous times link medicare mygov using linking code filling alternative link questions system not working.']",
#  '  [\'the "my.gov.au" not respond.  "mygov" went indian government site.  finally got  don\\\'t know  site would not recognise username. always bugger  site  got worse  quite suddenly\']',
#  '  ["typical gov cannot access anything  i\'m trying access. goes back forth without achieving anything.  basic login not basic "]',
#  "  ['i couldnt vote legislation 2fa app  track political donations real time blockchain']",
#  "  ['at least get firefox  instead use chrome  mainsite']",
#  "  ['coz lost phone number cant login.even hav password govid ']",
#  "  ['the site maintainance information extent not avaiable logged in. no information lenght delay.']",
#  "  ['i mygov account cannot access it. old lady 71 cannot remember password answers questions.  wrote somewhere.  now?']",
#  "  ['no full explanation unsuccessfully reset password ']",
#  "  ['there no help person ']",
#  "  ['unable log mygov all. soon try sign not load log returns sign page. details correct.']",
#  "  ['the website doesnt load ']",
#  "  ['ive followed app details registered  use website doesnt link!']",
#  "  ['the information spread out. many tiles distracting. ']",
#  "  ['you try tell not know answers secret questions ']",
#  "  ['my wife never read mail not log without something going wrong']",
#  "  ['it good ']",
#  "  ['your app locks password reset never works test shit release fools']",
#  "  ['because makes easy understand']",
#  '  ["dont\' count / sa checking form"]',
#  "  ['my gov helpful creating starting account well contact support im lost']",
#  '  ["tried log username password many times. not work!!"]',
#  "  ['could not find looking for']",
#  "  ['well thought still info screen beta experience appear  bottom looking ok next button! keen   thought  lets this! said ok  it? point little confused worked wasnt info screen may appear  actual mygov beta website. truth didnt really try links (believing demo photos  not actual links) dont feel got go mygov beta yet. asked it? felt ripped off! like missed out! mention im autistic  best possible way though. broken every iq test since first one 12yo rating 147. every iq test since says maxed 150  dont believe iq tests true  otherwise im smart struggle every single day complete basic daily tasks????']",
#  "  ['because annoyed n everything written not help me']",
#  "  ['your website sends clients pointless loops ']",
#  '  ["i used open letter  pay payg account. waste time trying understand message ca not print copy notice"]',
#  "  ['i stranded resident overseas  want pay payg  require australian sim card site rejected secret word  pay']",
#  "  ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  "  ['the hole system not working hard use ']",
#  '  ["it\'s true"]',
#  "  ['need simple answer question  incredibly hard get answer phone system']",
#  '  ["because tried reset password answers questions said wrong not wrong"]',
#  "  ['i tried change password mygov sending another username  not password ??????????']",
#  "  ['strongly agree']",
#  "  ['ino reason']",
#  "  ['the need obtain app code renter username password means code expired time get field enter it.  need freeze user name password go field get app code.']",
#  "  ['too b...y complex.   didnt end getting mygov 😡']",
#  "  ['think good']",
#  "  ['due fact changed mobile number unable login mygov - didnt access verification code. phone also cant call unable call help desk. ']",
#  "  ['agree ']",
#  "  ['i got no help accessing mygov inbox']",
#  '  ["because could not find information looking went old site. centrelink sent letter update form much easier find centrelink click form using old site. not want read documents portal - use google anything informational better."]',
#  "  ['i enter everyday email ..its  not accepted.. says need new email .. enter mobile number also not accepted   need find new email new mobile number sign ??? crn link code  centerlink cant  put anywhere always says email invalid ..yet centerlink office  front staff member good']",
#  "  ['it not work  every time try log problem. ']",
#  '  ["confusing website. not seem date many links websites defeats purpose "]',
#  '  ["i wanted find messages ato  no idea find them. would prefer clear simple navigation shows eg. \'ato\'  \'medicare\'  etc"]',
#  "  ['everytime insert username password select confirm password disappears try account locks up. really difficult! ive reset unlocked several times keeps occurring. still cant access account. wonder dont engaged why. cant!']",
#  "  ['limited control function elongated pages']",
#  "  ['once linked mygov medicare & ato  proving identity automatic ']",
#  "  ['useless']",
#  '  ["no matter try  email address use  still ca not access mygov site.  supposedly pending messages actions complete.  great effort "]',
#  "  ['i preferer old layout linked services only']",
#  "  ['it confusing not work time']",
#  "  ['i called overseas international phone cost  connected person talikng hang way coversation. need help phone hang centrelink.']",
#  "  ['it frustrating completing application seniors health care card.  first  not accept bank account details. secondly  not accept id documentation - not tell us go centrelink office provide id. ']",
#  "  ['very frustrating  unable log   password rejected several times responses security questions not accepted ']",
#  "  ['my gov nothing crap cant things go back like gov']",
#  "  ['hello 👋 ']",
#  "  ['your help desk phones keep dropping  spent 90 mins today trying get help  plus questions answered web site regurgitates stock info not answer service']",
#  '  ["how instead making second \'improved site\' make one works upgrade infrastructure"]',
#  "  ['have spent two hours trying update assets banking  site not let continue entering dates  even though entered format requested.']",
#  "  ['tasks within linked services appear mygov dashboard.']",
#  "  ['currently  beta site portal  linked services log redirect old site. confusing. ']",
#  "  ['cause']",
#  "  ['this not intuitive app. information difficult find format data displayed poor.']",
#  "  ['unable access mygov account new mobile number']",
#  "  ['information provided valuable bit overwhelming initially ']",
#  "  ['sent chase no apparent result.']",
#  "  ['i unable log even though details correct']",
#  "  ['the lost email lost password numbers.l entered not work. you. make bloody hard open anything password generated. not work.']",
#  "  ['eat shit']",
#  "  ['i tried access account using email address password came back details wrong typed forgot password got code  came back temporally locked out.not happy']",
#  "  ['looks good follow world standards info sites well done']",
#  "  ['because mygov easy efficient use always find useful helpful information']",
#  "  ['veryhard find relevant answers. no phone number included']",
#  "  ['i pretty used it.  however  find site obstructive use crns link services centrelink. added [youth allowance] parental income children successfully generated crn not me.  one gets stuck frustrating loop selecting not crn appears no affect.  honestly no idea whether not even online centrelink account even though entered details  mygov acc. mygovid.  nothing syncs!']",
#  "  ['because edit phone number ring you; something previous experiance takes long time get all!!']",
#  "  ['site not accepting correct day/date format personal drtails update section. multiple attempts made  tried logging back complete details everytime. probably go back centrelink try get resolved there. bad enough got terminated today.i also difficult time 3 years ago  first time ever tried get govt help due not able secure employment.']",
#  "  ['my password changes random threaten permanently bar me']",
#  "  ['hopeless not even medicare located gov.']",
#  "  ['if system crashed  not provide service']",
#  "  ['i need slightly tweak residential address appearing incorrectly. no option make edit. focussed fact changing something meant moving. im not. name tania mcinnes. residential address needs read following way file: 184 knights hill road knights hill 2577 nsw. thank :)']",
#  "  ['the information date answered questions looking for']",
#  "  ['the older generation not savvy']",
#  "  ['saves time & sale free moments ringing agencies.']",
#  "  ['unsatisfactory']",
#  "  ['because system not work still ring up']",
#  "  ['the information website fine']",
#  "  ['cant access account again.....']",
#  "  ['this worst thing get  terrible']",
#  "  ['because help desk number not readily listed.']",
#  "  ['the layout information flows natural engaging manner. compare experience recent encounter attempting navigate seemingly endless blue hyperlink trail plethora available assistance visually hard digest alphabetical organisation list led disarray instead grouped easily followed reaource.']",
#  "  ['fucking shit cant even log  gov account']",
#  "  ['there no easy way get passwords forget them']",
#  "  ['this hardest website get locked cannoit use ']",
#  "  ['the websit no help all. useless']",
#  "  ['because trying login gov forget login username sent request sent email 4 times still nothing yet']",
#  '  ["it wo not  give everything  "]',
#  "  ['your website doesnt work']",
#  "  ['i get information']",
#  "  ['where allowance payments worked  support pension payments allowance ...... disability pension support allowance dole payments dole payments allowance disa ']",
#  "  ['this difficult website navigate  no idea set access pathology report']",
#  "  ['i never get on. worst app made']",
#  "  ['the staff useless']",
#  '  ["keep going around circles unable link gov i\'d amy gov account  user unfriendly."]',
#  "  ['please ignore previous response form  trial error found needed open my.gov computer receiving codes via mobile phone. not noted attempting complete entire process phone proved impossible.']",
#  "  ['all tech much hard link anything log in']",
#  '  ["the language used not consistent  amount double ups information needed presented ridiculous  no government officer knows info next  fairly contradictory."]',
#  "  ['the site laid well easy navigate.']",
#  "  ['ttyt']",
#  "  ['easy undaerstand']",
#  '  ["i not look information reporting"]',
#  "  ['i hate getting sms code want log in']",
#  "  ['theres no choices shown future gov look like ']",
#  "  ['because doesnt work']",
#  "  ['it nothing age pension']",
#  "  ['mygov intimidating unfriendly. uses jargon']",
#  "  ['?? information']",
#  "  ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  "  ['was easy get help need']",
#  '  ["because never login \'mygov\' account  one occasion manage  got sent around circles  ended confused  headache."]',
#  "  ['the online process not supported action ']",
#  "  ['use gov app tiresome not easy use using old centrelink login']",
#  "  ['it impossible log mygov  & system not send username password codes details havnt changed. terribly stressful system not let log exceedingly long times. lost house 2019 fires & tax department intimidating cant lodge 3 years tax lost everything except shorts & torn shirt. nothing & tax department wants money form :(']",
#  "  ['on line lodgement need back turn around times  offer online updates never actioned']",
#  "  ['it seems current mygov']",
#  "  ['because report income receipt required. sometimes may forget print it. happened could get copy dashboard cannot removed. put back please!']",
#  '  [\'i get new phone number could no longer log mygov insisted verifying via phone secure code. get new email address sign new account. "help desk" people useless. zero help. \']',
#  "  ['no didnt work. no info provided wanted ']",
#  '  [\'accepting beta testing actual activity flicks back "real" website question think everyone ask changing site. new site looks fine  need get used neither better nor worse old one. think sentences everyones needs re-learn get around would helpful  please no fuffy nonesence like "we trying make mygov nicer experience making  site easier  navigate" thats meaningless rubbish also goimg tell people new site "more secure" immediately raise questions unsecurity old site ( ie current site ).  millions taxpayer dollars going upgrade? honest question :-)\']',
#  '  ["both ato & every gov dept not staff training various mygov mgovid authentication programs databases."]',
#  "  ['total crap! everything hinges code send. repeated attempts failed toget one.']",
#  '  ["i\'m looking mygov app. mygov id centrelink app neither give access mygov."]',
#  '  ["i difficulties multiple usernames mygov website (even gp466433).  change password allowing change password login saying there\'s error!  reset password yet again!  please suggest previous accounts expunged!  thanks."]',
#  '  ["the website hopeless not allow freedom choices. forces answers upon continues loop"]',
#  "  ['because log process crap every time asked access account not accept passwords permantly loc ked fix b loody thing stop asking people access it']",
#  "  ['uploaded documents 03/03/2021 not actioned']",
#  "  ['did not check beta site  using feedback form cannot find way contact mygov without calling']",
#  "  ['because system frozen va cant help basically system stuffed getting help offices line joke']",
#  "  ['https://i.imgur.com/doxgape.png']",
#  "  ['cant login']",
#  "  ['spent 30 min making gov id  try log onto mygov says details wrong. fucking frustrated']",
#  "  ['i received information assistance required']",
#  "  ['i endless problems linking account ']",
#  "  ['i didnt answer question no code sent email mobile ']",
#  "  ['the system says 3 unread messages  however  cannot tell messages unread.']",
#  "  ['i locked account made phone call told sorted problem could try twenty minutes waited till next day still wont let get passed password stage even though im using suggestion strong password create new account ']",
#  '  ["ca not log in"]',
#  "  ['this worst site ever displeasure trying log into. still cannot log check messages!!! horrible!!']",
#  "  ['gov ongoing joke']",
#  '  ["it\'s well designed. quite easy move around. really enjoy it."]',
#  '  [\'too convoluted "busy" main page\']',
#  "  ['i simply went round round cirlces got nowhere. unhelpful routine ever encountered!']",
#  "  ['because hard log  well nuisance anyway']",
#  "  ['when u tell name wrong u complete fuck']",
#  "  ['quite limited possible do']",
#  "  ['fhfdg']",
#  '  ["same  not given info yet"]',
#  '  ["because trying save money crap online system not work bring back regular bas form posted save garbage"]',
#  "  ['there no option say want opt jobseeker payment got permanent job. assume basic feature forcing enter money received multiple weeks confusion applying jobs satisfy requirements already one..']",
#  "  ['i need see change actual options offered.  especially around childcare mutual obligations. ']",
#  "  ['cant login ']",
#  "  ['tasks need better explained!']",
#  "  ['you cant offer answers pertaining neurologically damaged applicants.']",
#  "  ['im struggle create account ']",
#  "  ['read previous answer']",
#  '  [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  "  ['as per previous answer']",
#  "  ['you incredibly poor communicators. dont think even get mygov']",
#  '  ["i not fit box government trying squeeze us into."]',
#  "  ['yes  im live share mom house 2 bedrooms. address 2 beevers st footscray vic 3011  1 month $500. yes  help mores money payment share moms thank much there.']",
#  "  ['sign-in procedure difficult']",
#  "  ['thank much ']",
#  "  ['no way much  crap  wade through. ']",
#  "  ['after successfully login account :  jk728811  screen displayed “  loading please wait upper address bar running many many “auth callback” code addresses 5 minutes  back !!!!   gone !   ']",
#  "  ['shit site']",
#  '  ["obviously instructions not precice."]',
#  "  ['well written easily understood ']",
#  "  ['as true best knowledge ']",
#  "  ['because always sticks']",
#  "  ['agree']",
#  "  ['i want apply new medicare care cant ']",
#  "  ['helping bit accurately thanks ']",
#  '  [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  "  ['both mygov mygov beta sites poor nil trouble shooting help']",
#  "  ['i trying login centrelink via mygov without success.']",
#  '  ["i ca not get in"]',
#  "  ['because no option add pay slip summaries employment income services . need email whereas could upload account update income asset section. also impossible see whole picture assets. disintegrated. worse website development ever']",
#  "  ['repeat chat services stupid irrelevant not answer question!!!!!!!']",
#  "  ['i felt informed']",
#  "  ['despite lengthy format  eventually completed task. lengthy format made confusing.']",
#  "  ['could see things use most']",
#  "  ['see previous answer']",
#  "  ['i could not access account old mobile number attached it.']",
#  "  ['please delete mygov account: username: elvis.nguyen.zero@gmail.com']",
#  '  ["all wanted apply sickness benefits spent 3 days still not know right "]',
#  "  ['information insufficient ']",
#  "  ['locked site 2 hours']",
#  "  ['not useful']",
#  "  ['i use centrelink health sections available ']",
#  "  ['possibly many steps']",
#  "  ['no relevant circumstances need assist waiting answer ']",
#  "  ['too centre link orientated']",
#  "  ['i agreed information found relevant & circumstances']",
#  '  [\'the problem remains solved update issues faced simply trying login account. cannot login  services available  no matter well designed information  easily found  cannot used first place. not believe ever experience logging mygov occurred without issue  whether australia overseas. present  required set secure login password  serves almost no purpose always required enter code. beauty process code must either sent text message  \\\'generator app\\\'  course  phone. unhelpful don\\\'t access phone  not mention infuriating solution "i cannot access device/i lost device (i.e. app installed)"  "select receive sms". possible receive sms device not  fact not reason you\\\'re stuck first place?  accept 2021 need receive code addition password every single time login  code generator app sounds amazing! problem  doesn\\\'t work - see return scenario outlined  alternatively  you\\\'re overseas haven\\\'t lost device per se  still cannot receive sms: end result. back code generator app itself. managed use one  going process setting up. set app  to.... guessed - login! using sms receive code! hilarious considering setting precisely not use sms code  better hope remember set realise need (magic future telling powers required). manage foresight  somehow thought would save repeating nightmare circle dance logging mygov  think cracked it! however  trying use simple sounding login password + secret code generator app today  open app find without code. set scene: website simply says "enter code mygov code generator app. didn\\\'t get code? click send code via sms". app says  "about app: app generates codes enter sign mygov account. you\\\'ve set app  can..." oh  helpful. point options are: (1) request code via sms - cannot receive sms\\\'s overseas  course set app first place (refer first problem mentioned). (2) select \\\'continue\\\' app - beautiful thing. select continue takes process setting account. re-enter login details  useless password  hit submit.  says pure comedy gold: "your device already registered. please login remove device want set again". yes  that\\\'s right. app need use login telling need login use it. not need explain ridiculous is. course  remaining option call centerlink   alas  line hangs time get through. want finish tax return  all.  spending incredible amount money bring website content visuals user accessibility 21st century  please ensure users actually access traditional sense word - simply login. without basic functionality  site entirely useless. thanks advance! regards  tax payer.  \']',
#  "  ['alwys look safty too']",
#  "  ['only trying get access mygov. keep simple e.g car licence no']",
#  "  ['when asked question sign answers given not applicable ']",
#  "  ['you keep going round circles ']",
#  "  ['i cant login. lot keep changing bloody process. ffs']",
#  "  ['it not exist ']",
#  "  ['because convinced sure helps me']",
#  "  ['there no relevant no easy way navigate. ']",
#  '  ["i could not needed done."]',
#  '  ["you try cover possibilities without understanding doing"]',
#  "  ['same last answer']",
#  "  ['whoever framed survey obviously little understanding user requirements. question confusing appears no relevance specifics. perhaps use example would helpful.']",
#  "  ['all false wont even let log wait 2 hours cause site garbage ']",
#  "  ['all information require not file']",
#  "  ['people helped me']",
#  "  ['convoluted & confusing']",
#  "  ['there no assistance particular difficulty']",
#  "  ['because information incorrect ']",
#  "  ['see previous']",
#  "  ['found info not looking for']",
#  "  ['n/a.']",
#  "  ['as  need help genetic help offer']",
#  "  ['great personalised information']",
#  "  ['it true']",
#  "  ['i included.']",
#  "  ['it bit generic']",
#  "  ['i need new password']",
#  "  ['i click find login link']",
#  "  ['limited online functionality forces call multiple occasions resolve matter coupled excessive hold times no call back service offered you']",
#  "  ['no phone']",
#  "  ['mygovid sucks']",
#  "  ['because didnt want information. thought would able log centrelink easier  not']",
#  "  ['it impossible log gov site']",
#  '  ["there minimal information  hard find bugs usually prevent loading it"]',
#  "  ['my answer']",
#  "  ['no']",
#  "  ['maybe ']",
#  "  ['wrong information not helpful ']",
#  "  ['less paper work ']",
#  "  ['the questions suggested pension card not yet have.  no provision entering alternative information enable login']",
#  "  ['system useless']",
#  "  ['crashes time']",
#  "  ['the information found relevant needed know.']",
#  "  ['lnp propaganda make legal benefits difficult receive']",
#  "  ['payment information date useful show type payment page ']",
#  "  ['i made comment no feedback.']",
#  "  ['see previous response ']",
#  "  ['your apps logins trash ']",
#  "  ['as stated previous response  service looking  centrelink service  not page.']",
#  "  ['cannot link medicare attempted numerous times page keeps returning original screen not going next']",
#  "  ['my pervious answer  could not get on']",
#  "  ['unable access information ']",
#  "  ['legislation wasnt put laymans terms inform rights obligation australian citizen ']",
#  "  ['xyz']",
#  "  ['            \\xa0                                                   .']",
#  "  ['he site maintainance information extent not avaiable logged in. no information lenght delay.']",
#  "  ['not straight forward ']",
#  "  ['same answer previous ']",
#  "  ['nil']",
#  "  ['as per previous statement. ']",
#  "  ['i cannot sign gov telling wrong thing']",
#  "  ['it job ndis ']",
#  "  ['your app worthless uselesscrap worse last pathic efforts scamming fo govt dollar ']",
#  "  ['same service works fine area']",
#  "  ['same first answer']",
#  "  ['i didnt find info.']",
#  '  ["i want create new account code not sent  wasting time"]',
#  "  ['your website overloaded deliberately confusing']",
#  '  [\'it waste time. ask question some"virtual" machine gives rubbish answer. taxpayer it\\\'s not good enough. use human please\']',
#  "  ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  "  ['the system not working hard use ']",
#  "  ['liked']",
#  "  ['as above']",
#  '  ["because not get wanted"]',
#  "  ['who writes things']",
#  "  ['no reason']",
#  "  ['because not work']",
#  "  ['strongly disagree ']",
#  "  ['no help all']",
#  '  ["i could not find information "]',
#  "  ['not relevant all']",
#  "  ['i log mygov things  read messages  make medicare claims  etc. current site seems like unstructured list informational pages not want.']",
#  "  ['their nothing starting maintaining small business']",
#  '  ["no good married woman asked give birth certificate details told not match no options"]',
#  '  ["still ca not access site  no matter option select"]',
#  "  ['i click centerlink old website linked services']",
#  "  ['i called overseas international call hang centrelink officer. called expensive cost?']",
#  "  ['was unable find information due system glitch']",
#  "  ['hello. locking account gov']",
#  "  ['cannot get discuss no provision callback email assist']",
#  '  ["could not login - stop hiring software developers  start upgrading hardware. cannot run shit servers 90\'s"]',
#  "  ['the information relevant not accessible ']",
#  "  ['because believe ']",
#  "  ['as usually logging mygov due wanting perform required tasks  found tasks home page streamlined experience.']",
#  '  ["that\'s feel"]',
#  "  ['data ok presentation format poor.']",
#  "  ['unable access']",
#  "  ['there clear feedback enquire progressed  took searching confirm query']",
#  "  ['the system stalled early stage.']",
#  "  ['unable find information could not log site']",
#  "  ['get real listen customers  nerds put pages not user friendly']",
#  "  ['eat shit']",
#  "  ['accurate']",
#  "  ['i\\\\the form joining gov security refused accept genuine passwords fulfilling criteria.']",
#  "  ['you change password random threaten permanently bar use it']",
#  "  ['i told you']",
#  "  ['i told before.']",
#  "  ['see previous']",
#  "  ['you cant log create account dont email address']",
#  "  ['provides easy ness claim online.']",
#  "  ['unsatisfactory']",
#  "  ['its no good']",
#  "  ['info assisted helping start account']",
#  "  ['still cannot access account know details stupid app']",
#  "  ['trying get hopeless']",
#  "  ['the help desk number not available.']",
#  "  ['sucks']",
#  "  ['need find better ways change passwords forgotten dont phone']",
#  "  ['why u lock people website ']",
#  "  ['useledd']",
#  "  ['why not???????? cannot access anythinhg till get details']",
#  "  ['i not get information']",
#  "  ['i keep going around circles  logging mygov  getting no sign achieved anything']",
#  "  ['can not get information ']",
#  "  ['unable login dont get codes sent me']",
#  "  ['totally confused']",
#  '  ["i could not find information needed"]',
#  '  ["i looking child support payment information not live beta yet."]',
#  "  ['ytryr']",
#  "  ['easy']",
#  "  ['i not look information  reporting']",
#  "  ['mygov doesnt seem personalised currently disjointed ']",
#  "  ['it sent loop doesnt work']",
#  "  ['my circumstances limited eligible age pension  nothing age pension site']",
#  "  ['i professional engineer working designing human interface solutions. mygov breaks many guidelines rules  good design. logged today access mygov message.  would not display message. content many mygov messages not particularly private could included personal email  thereby avoiding pain intimidation logging mygov together.']",
#  "  ['????']",
#  "  ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  "  ['was relevent search']",
#  "  ['because not sign account. twice successfully managed sign in. tried using “forgotten username “ never receive email even though email address otherwise would not receive mail telling messages! ']",
#  "  ['i believe information ambiguous make it. ']",
#  '  [\'the onliune process not fully supported manual intervention ie:" keeping records date \']',
#  '  ["it\'s not user friendly older persons"]',
#  "  ['because information confusing & isnt helping ever.']",
#  "  ['it seems current mygov']",
#  "  ['no comment']",
#  "  ['see last comment.']",
#  "  ['not answering question ']",
#  "  ['this information found production version mygov ato  centrelink....so course relevant ! otehr information asking about?']",
#  "  ['gov staff not trained computer science.']",
#  '  ["did not work"]',
#  "  ['how connect mygov?']",
#  "  ['online updated information seems get lost not actioned']",
#  "  ['see previous answer']",
#  "  ['because no help no one cares']",
#  '  [\'"you one task do" ... could not today. report income. wasting people\\\'s time. income today tomorrow not change. write systemic procedural problem  not website one. guess what? one end users!\']',
#  "  ['cant login']",
#  "  ['all information relevant situation assisred me']",
#  "  ['its account l need link gov']",
#  "  ['you didnt answer question ']",
#  "  ['i cant achieve want ']",
#  "  ['unable lig using phone']",
#  "  ['impossible log in!']",
#  "  ['gov ongoing joke']",
#  "  ['nothing relevant ']",
#  '  ["did not really find anything useful go through"]',
#  "  ['m']",
#  "  ['same before']",
#  "  ['i think seemingly confusing conflicting information offered.  ']",
#  "  ['cant login ']",
#  "  ['you hate disabled people']",
#  "  ['not ']",
#  "  ['it incorrect']",
#  '  [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  "  ['it not easy update assets.']",
#  '  ["the first time reported new system confusing ca not report all"]',
#  "  ['information didnt work']",
#  '  ["unable access information looking for... not guys employ unemployed qualified jobseekers? plenty... know (with fantastic systems)"]',
#  '  ["ato reques\'d feedback. kept returned \'the info. found etc\' page input could not sent"]',
#  "  ['thank much ']",
#  "  ['there icons services  may select not sure works']",
#  "  ['absolutely no information help']",
#  "  ['when followed access denied.']",
#  "  ['i understood everything presented']",
#  "  ['because neither agree disagree']",
#  "  ['very good']",
#  "  ['yes please thanks ']",
#  '  [\'site says overseas australians "contact us calling +61 1300 1mygov (1300 169 468)" 1300 numbers not work overseas\']',
#  "  ['no particular reason.']",
#  '  ["despite repeatedly signing correctly  including changing password said wrong (it not) waiting 2 hours try facing another 2 hours try then... beta site failure"]',
#  "  ['much harder account. services complicated use website']",
#  "  ['repeat previous statement']",
#  "  ['i would liked details type paymsnt recieved ']",
#  '  ["due information multiple pages (before easily attained processed one page) jumble presentation."]',
#  "  ['i found no information']",
#  "  ['i didnt search information able access inbox']",
#  "  ['i could not access account old mobile number attached it.']",
#  "  ['please delete mygov account elvis.nguyen.zero@gmail.com']",
#  "  ['like said totally confused superanuation companies not much help finding information wanted ']",
#  "  ['locked 2 hours']",
#  "  ['the options available clear understand']",
#  "  ['the information needs ']",
#  "  ['yes  generally clearly articulated']",
#  "  ['i agree  information found easy understand']",
#  "  ['test']",
#  "  ['very nice exces understand ']",
#  "  ['my question not answered']",
#  "  ['useful explanation points']",
#  "  ['same ']",
#  "  ['cant access it']",
#  "  ['it not exist']",
#  "  ['really  get well']",
#  "  ['it easy understand completely unhelpful. ']",
#  '  ["the information not helpful finish reporting."]',
# ...
#  "  ['all changes must mean apps arnt secure']",
#  "  ['the two gactor authentication makes feel secure login details ']",
#  '  ["i\'m optimistic dept. :-)"]',
#  "  ['i used mygovid ']",
#  "  ['mygov relies two factor authentication using sms. sms not secure. option use totp authenticators  services accessed overseas  without access australian mobile number.']",
#  "  ['i could not access account old mobile number attached it.']",
#  "  ['its safe provide mygov application use phone helpful ']",
#  "  ['forced use mobile phone  unsubsidized expense coercion blackmail. please delete account: username: elvis.nguyen.zero@gmail.com']",
#  "  ['we find future government department not got good record ']",
#  "  ['locked 2 hours not get on']",
#  "  ['i trust government departments keep info safe']",
#  "  ['seems secure far']",
#  "  ['i never feel safe site online time ']",
#  "  ['i like 2 factor authentication. prefer not using biometrics (eg voice print per phone service)']",
#  "  ['i agreed fact felt safe & secure using mygov beta']",
#  "  ['hello']",
#  "  ['to technolical advantage use protect ']",
#  "  ['i could not sign out']",
#  '  ["well  hope secure"]',
#  "  ['what gov beta?']",
#  "  ['its safe no bastard get ']",
#  '  ["fuck no not "]',
#  "  ['because really feel safe comfortable using gov']",
#  "  ['i no way knowing.  no way verifying site - even login could pretending mygov harvesting credentials.  needs way greeted information mygov knows user not entered user login. ']",
#  '  ["i ca not say anything program yet."]',
#  "  ['have no confidence security interest.']",
#  "  ['how website leave feeling anything? either works provide information (in case not)  not.']",
#  "  ['what ???? safe secure?????? complaint digital id tried log 10 times without success.']",
#  "  ['because security top notch']",
#  "  ['humans assisted me']",
#  "  ['doubt whether system really secure ']",
#  "  ['definitely not']",
#  "  ['feel?']",
#  '  ["if ca not find info sure others ca not also"]',
#  "  ['n/a.']",
#  "  ['cant log cant get point feeling safe']",
#  "  ['i wont share']",
#  "  ['feel uneasy giving opinion ']",
#  '  ["was not able login check security felt comfortable"]',
#  "  ['i zero trust faith mygov now... well max employment(joke century) centrelink. max calked (appointment) hng uo putting phone loudspeaker...now instantly   suspended   again...']",
#  "  ['because no worries all']",
#  '  ["government australia terrible history data security  no reason believe safer here"]',
#  "  ['no']",
#  "  ['who knows whos im web couldnt login ']",
#  "  ['in good hands ']",
#  '  ["i not know enough application."]',
#  '  ["i ca not access anything!"]',
#  "  ['i go office ever health problems']",
#  "  ['easy anyone hack']",
#  "  ['i believe using site safe.']",
#  "  ['i never use unless get printout wipe with']",
#  "  ['same original mygov website']",
#  "  ['see previous response ']",
#  "  ['i dont trust info anyone']",
#  "  ['your apps logins trash ']",
#  "  ['could not use']",
#  '  ["yes could not accessanything "]',
#  '  ["this country gives data away  5 eyed alliance creating criminals poor jurisprudential authorty"]',
#  "  ['have not tested yet']",
#  "  ['see answer 1 2 3']",
#  "  ['very frustrated']",
#  "  ['if cant link data secure databases would trust personal information. ']",
#  '  ["you rely much mobile phone numbers.  change endure long wait phone get sign changed. ca not make reliable email least make changes accessible us?"]',
#  '  ["if fo not correct information  coukd possibly ferl safe.  must realise know mothers grandmother\'s maiden names use secret questions.  yet  gov tell zi wrong   sm sorry  wrong."]',
#  "  ['same before']",
#  "  ['it password ']",
#  "  ['while gov secure lose phone number deleted code gen app im forced deleted whole gov account start  rather answering secret questions not even gov phone line update details!!']",
#  '  ["if ca not trust gov  trust"]',
#  "  ['because hack choose not  im good person. also choose not hack bank add zeros balance. build pathetic little 15mhz computer doesnt ability leave online tracks. leave cant know already once. know current nsa password know intend changing next  dont believe know going change yet! lmao! (change theory guys  autistic people see answers!;) . no one ever really safe online! fact.']",
#  '  [\'have laugh one makes thinking swaddling baby  plus no one feel safe n secure days cant even afford buy scripts. wld feeling "safe n secure"\']',
#  "  ['it deliberately designed deter people using it.']",
#  "  ['another machine! another frustration!!!!']",
#  "  ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  "  ['the system doesnt work ']",
#  "  ['true']",
#  "  ['again  not issue  trying find simple answer']",
#  "  ['do twist arm identity id  no way']",
#  "  ['no reason']",
#  "  ['strongly agree ']",
#  "  ['i home']",
#  "  ['no im upset centerlink people said going easy ..your joking .i need go back sort face face ']",
#  "  ['the website seems less official gov websites']",
#  "  ['i feel frustrated ']",
#  "  ['did not get anywhere system']",
#  "  ['no solutions offered']",
#  "  ['huge online data bases get hacked time']",
#  "  ['was unable access  system locked out']",
#  "  ['it irrelevant cannot get stay connected!']",
#  "  ['could not login']",
#  "  ['a modern responsive interface gives impression website looked us security data.']",
#  "  ['the beta site incomplete']",
#  "  ['good']",
#  "  ['superficial security good  ....']",
#  "  ['i cannot tell secure would be. not seem sensible perhaps not secure.']",
#  "  ['unable use it']",
#  "  ['it not user friendly ']",
#  "  ['no']",
#  "  ['true']",
#  "  ['no fallback positionj help phone number']",
#  "  ['you change password random threaten permanently bar use it']",
#  "  ['.']",
#  "  ['two factor authentication works well']",
#  "  ['nobody get details safe- reason couldnt enter them']",
#  "  ['my pin sign on/off mine unless compromised.']",
#  "  ['yes  little secure since whole gov deleted due phone number chnaged ']",
#  "  ['tell team not tell rebuild account....stupid info']",
#  '  ["the page l could get  could not get mygov all"]',
#  "  ['what point question?']",
#  "  ['rather old way centrelink']",
#  "  ['did not get anything.']",
#  "  ['cant even log in. takes almost 30min secure code arrive.']",
#  "  ['why would anyone take trouble - nothing see here']",
#  "  ['keeps blocking ']",
#  "  ['cant get account  doesnt send codes  staff cant reset']",
#  '  ["did not work guess still secure"]',
#  "  ['safe guards']",
#  "  ['the website doesnt feel secure authenticated app - ie webpage could anything. make similar secure bank apps ']",
#  "  ['it sent loop ']",
#  "  ['i trust every government site']",
#  "  ['it feels like designed committee focused security fulfilling basic function simplest easiest way']",
#  "  ['i want give feedback only']",
#  "  ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  "  ['yes feel safe']",
#  '  ["my answers probably wo not make difference."]',
#  "  ['safe cyber crime not centrelink bias ']",
#  "  ['too difficult']",
#  "  ['i dont feel safe using type servey havnt successful elsewhere  never feel safe using mygov.']",
#  "  ['the ui mygov beta harder navigate - apart new dashboard old mygov easier use navigate.']",
#  "  ['not sure']",
#  "  ['see last comment.']",
#  "  ['i trusting is']",
#  "  ['i concerns dta privacy security leaks hacks system vulnerabilities due bad coding poor testing thats current system. think gov generally poor security general.']",
#  "  ['this authentication going backwards & making every user vulnerable.']",
#  "  ['rubbish']",
#  "  ['nothing online really safe.']",
#  "  ['i want able access laptop ease']",
#  '  ["afaik see no details strong  weak  encryption setup is. https nothing without strong implementation  across sites make users sidelogin jump around  whilst trying plaster cracks make \'unified\' website still-disparate  double-handling  invariably separated increasingly irrelevant  ancient gov dept silos (centrelink  ato  etc)."]',
#  "  ['cant login']",
#  "  ['ease use']",
#  "  ['hardly used ']",
#  "  ['i dont think online platform reliable ']",
#  "  ['i no trouble previous system dont see changed causing stress']",
#  "  ['still cant log mygov!']",
#  "  ['gov ongoing joke']",
#  "  ['nothing concerning note']",
#  "  ['no']",
#  "  ['your kidding right']",
#  "  ['no. want give feedback  no option  agree policy sharing data outside company. way survey giving information government not third parties.']",
#  "  ['i friend whose information illegally accessed sold government employees. no system infallible. however id like see automatic 2 year jail term applies access information illegally criminal purposes even ‘only helping mate.  no matter government system.  ']",
#  "  ['ridiculous ']",
#  "  ['youre private company. profit neglected.']",
#  "  ['read previous andwer']",
#  '  [\'i wasn\\\'t looking information  curious website would look like. first thing noticed person african decent "jobkeeper" picture  white anglo blonde "health services". think would great opportunity subtly reflect true australia. not doctor someone first nations background. not person applying jobseeker older man woman background looks like they\\\'ve steady job whole life holden factory gets shut coles factory decides warehouse automation machines instead using dedicated employees. govt giving incentives businesses hire younger people  40s&gt; age bracket requiring jobseeker more. \']',
#  '  ["i not know does."]',
#  "  ['as per previous answer']",
#  "  ['if cant operate program  trusted ...could trustef']",
#  "  ['robodebt  hacking australian systems... please. whole continent gone hill government']",
#  "  ['thank much ']",
#  "  ['may be']",
#  "  ['givernment generally useless keeping things private']",
#  "  ['mygov beta provided information made feel privacy secure']",
#  "  ['who knows?']",
#  "  ['very good']",
#  "  ['very helpful framework consistently constant ']",
#  "  ['experience today changed opinion']",
#  "  ['well hope safe']",
#  "  ['big brother joke ']",
#  "  ['pfft']",
#  "  ['the two favor authentication makes feel secure login details ']",
#  "  ['…unless really goes downhill  hopefully important standards monitored  place ongoing.']",
#  '  ["i could not access account old mobile number attached it. not know received security code not confident information secure. "]',
#  "  ['nope']",
#  "  ['we see']",
#  "  ['no faith ']",
#  "  ['could not even see details ']",
#  "  ['hopefully technology government departments use secure']",
#  "  ['because info & steps quite hard fake!']",
#  "  ['i not trust mygov beta protect privacy times not monitoring process site ']",
#  "  ['until hackers get in.']",
#  '  ["mygov lot personal information. bank statements  investment records  etc. i\'d prefer not much personal info one agency."]',
#  "  ['i agreed trusting mygov beta  protecting privacy & security']",
#  "  ['it undercontrol govt australia']",
#  "  ['there always hackers']",
#  "  ['this getting waist time ']",
#  "  ['yep. not even access it. ']",
#  "  ['it true cove trustworthy respectful']",
#  "  ['who knows -https://dta.syd1.qualtrics.com/jfe/form/sv_e9bkxymmpm12iy9 could scam. user no option trus you.']",
#  "  ['i trust mygov protect personal information.']",
#  "  ['i no reason believe  either']",
#  "  ['i not even know mygov beta  trial feedback line. ']",
#  '  ["no idea checks balances ca not comment."]',
#  "  ['i ex government employee . know security']",
#  "  ['too many people much access']",
#  "  ['no confidence']",
#  "  ['trust government?  hahahah']",
#  "  ['seems secure']",
#  "  ['n/a.']",
#  "  ['this site hard use']",
#  "  ['i trust it']",
#  "  ['the government pretty trustworthy.']",
#  "  ['too many terms conditions forms click through']",
#  '  ["do not know running behind ensure site secure"]',
#  "  ['suspect prone overseas hack']",
#  "  ['already answered']",
#  "  ['they think would look security ']",
#  "  ['statistically likely data breach. government consistently downplays implications ruin lives']",
#  "  ['no']",
#  "  ['so far cant trust telling something falls couldnt perform task told ']",
#  '  ["i\'m sure previous experience "]',
#  '  ["i not know enough security site."]',
#  "  ['i cannot access anything!']",
#  "  ['useless nothing']",
#  "  ['security  security !!   personal information easy hack']",
#  "  ['there always concerns accessing websites.']",
#  '  ["stupid idea giving private firms people\'s personal data. not access"]',
#  "  ['being beta not confident full website']",
#  "  ['see previous response ']",
#  "  ['your apps logins trash ']",
#  "  ['i cannot even link account must secure!']",
#  "  ['i suppose nobody else access cannot']",
#  "  ['no blockchain  trust much open source replicatesd peer reviewed laboratory experiment']",
#  "  ['as before']",
#  "  ['see answers 1 2 3']",
#  "  ['its secure cannot access no use me']",
#  "  ['data security obviously issue mygov app website. ']",
#  "  ['hiw trust gov cannot get information correct !!!']",
#  "  ['it easy ']",
#  "  ['easy']",
#  "  ['yes security accounts good not even get account (allow option get in)']",
#  '  ["why not i"]',
#  "  ['read previous response!!!! yahoo serious? mean... serious guys?']",
#  "  ['thats difficult one.it shld trust u protect life n trust no one']",
#  "  ['website didnt work iphone se running chrome. beta suffers compatibility issues. make impossible 2 000 000 others use it.']",
#  "  ['the web site terrible use ']",
#  "  ['true']",
#  "  ['assume would']",
#  "  ['you leaked information former employer not relevant information well. no answer']",
#  '  ["what\'s stupid fucking questions?"]',
#  "  ['strongly agree ']",
#  "  ['imshared no privacu system frustratingly unhelpful']",
#  "  ['you cant even find email address ive using years.. always invalid']",
#  '  ["gov websites history problems regard. changing visual design wo not change track record."]',
#  "  ['the last online census']",
#  "  ['should able get information linked services']",
#  "  ['no help given']",
#  "  ['i agree would attempt so']",
#  "  ['i trust privacy security protected. ']",
#  "  ['cyber security not 100% ']",
#  "  ['if cannot get  suppose privacy protected!']",
#  "  ['could not login']",
#  "  ['i find sign mygovid quite disregarded low hidden sign page  comfortable way login.']",
#  "  ['i dont judge.']",
#  "  ['see previous']",
#  "  ['to extent  confidence govt records secure.']",
#  "  ['cant login cant achieved protect information']",
#  "  ['read previous text ']",
#  "  ['no']",
#  "  ['true']",
#  '  ["it\'s impossible access site anyway"]',
#  "  ['two factor authentication']",
#  "  ['the government allowed keep pin  sign on/off confidential.']",
#  "  ['i no doubt keep safe']",
#  "  ['great privacy cant open account']",
#  '  ["why reason not?"]',
#  "  ['dont belueve shit']",
#  "  ['hopeless']",
#  "  ['can never get see']",
#  "  ['ask many personal questions']",
#  '  ["do not trust government look interests "]',
#  "  ['it gov regards privacy security guess.']",
#  "  ['priof']",
#  "  ['i agree privacy policy says data may go overseas unnecessary close option make secure australians ']",
#  "  ['it sent loop']",
#  "  ['i trust official sites aust governments reputable businesses.']",
#  "  ['anything looks like designed committee cannot fully secure private']",
#  "  ['no idea']",
#  "  ['my name frank qualtrics canberra - please contact 02 8310 8032 help improve response rates!']",
#  "  ['i trust website']",
#  "  ['it must safe even cant access it.']",
#  "  ['most politicians corrupt days.']",
#  "  ['pretty safe']",
#  '  ["could not use "]',
#  "  ['no dont trust anything government more.']",
#  "  ['the ui mygov beta harder navigate - apart new dashboard old mygov easier use navigate.']",
#  "  ['not sure']",
#  "  ['see last comment.']",
#  "  ['i believe so']",
#  "  ['i concerns dta privacy security leaks hacks system vulnerabilities due bad coding poor testing thats current system. think gov generally poor security general.']",
#  '  ["no user trust government staff not even understand security protocols."]',
#  ...]

# %%
stopwords = nltk.corpus.stopwords.words("english")

words = [w.lower() for w in nltk.word_tokenize(all_string) if w.lower().isalpha() if w.lower() not in stopwords]

#words: list[str] = nltk.word_tokenize(all_string)

# frequency distribution
fd = nltk.FreqDist(words)
df = pd.DataFrame(list(fd.items()), columns = ["Word","Frequency"]) 
df.to_csv('data/output/frequency_distribution.csv')
fd
# Out:
# FreqDist({'mygov': 175, 'information': 172, 'get': 149, 'use': 130, 'account': 116, 'access': 109, 'help': 108, 'login': 98, 'site': 88, 'could': 86, ...})

# %%
# Trigram finder
finder = nltk.collocations.TrigramCollocationFinder.from_words(words)

finder.ngram_fd.most_common(5)
finder.ngram_fd.tabulate(5)
# Out:
# ('information', 'curious', 'website')          ('code', 'generator', 'app')        ('name', 'frank', 'qualtrics')    ('frank', 'qualtrics', 'canberra')   ('qualtrics', 'canberra', 'please')
#                                     8                                     8                                     8                                     8                                     8

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from statistics import *
sia = SentimentIntensityAnalyzer()

def extract_features(text):
    features = dict()
    compound_scores = list()
    positive_scores = list()
    negative_scores = list()

    for sentence in nltk.sent_tokenize(text):
        compound_scores.append(sia.polarity_scores(sentence)["compound"])
        positive_scores.append(sia.polarity_scores(sentence)["pos"])
        negative_scores.append(sia.polarity_scores(sentence)["neg"])

    # Adding 1 to the final compound score to always have positive numbers
    # since some classifiers you'll use later don't work with negative numbers.
    features["mean_compound"] = mean(compound_scores)
    features["mean_positive"] = mean(positive_scores)
    features["mean_negative"] = mean(negative_scores)
    return features
features = extract_features(all_string)

# %%
# Calling the polarity_scores method on sid and passing in the message_text outputs a dictionary with negative, neutral, positive, and compound scores for the input text
scores = sia.polarity_scores(all_string)
scores
# Out:
# {'neg': 0.109, 'neu': 0.709, 'pos': 0.182, 'compound': 1.0}

# %%
all_scores = (features.update(scores))
df = pd.DataFrame(list(features.items()), columns = ["Metric","Score"]) 
df.to_csv('data/output/vader_polarity_scores.csv')

# %%
df
# Out:
#           Metric     Score
# 0  mean_compound  0.033472
# 1  mean_positive  0.128755
# 2  mean_negative  0.125654
# 3            neg  0.109000
# 4            neu  0.709000
# 5            pos  0.182000
# 6       compound  1.000000
